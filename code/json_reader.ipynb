# %%
import json
import cv2
import os
import argparse

import numpy as np
import matplotlib.pyplot as plt

# %%
def get_findings_segments(path, file):
    """gets a filename and return"""
    
    json_filename = path+file+'.json'
    with open(json_filename, 'r') as f:
        tag_dict = json.load(f)
    
    findings = tag_dict['videoFindings']
    segments = tag_dict['videoSegments']
    
    return findings, segments

# %% [markdown]
# ## Function to extract frames
# TODO:
# - add parser
# - problem for flere findings i samme frame
# - cv2 resize

# %%
def save_findings(video, findings, path, file, verbose):
    count = 0
    next_frame = 1
    
    while next_frame:
            # video object calls read and extract next frame
            next_frame, image = video.read()

            # Obs - problem for samme frame i flere id
            for id in findings:
                lesion_name = id['name'].replace(" ","")
                frames = id['shapes']

                if str(count) in frames.keys():
                    # Saves the frames with frame-count
                    for frame, shapes in frames.items():
                        x,y = [], []
                        for xy in shapes:
                            x.append(round(xy['x']))
                            y.append(round(xy['y']))
                        save_image = None
                        #image_crop = image[x[0]:x[1], y[1]:y[2]]
                        test = image
                        cv2.rectangle(img = test, pt1 = (x[0], y[0]), pt2 = (x[2], y[2]),color = (0,255,0),thickness = 2)
                        cv2.imwrite(path+file+"/%s_%d.jpg" % (lesion_name, count), test)
                        if verbose: print ("saved finding frame %s - pt1=(%d, %d), pt2=(%d, %d)" % (frame, x[0], y[0], x[2], y[2]) )
            count += 1

# %%
def save_segments(video, segments, path, file, verbose):
    count = 0
    next_frame = 1
    
    while next_frame:
            # video object calls read and extract next frame
            next_frame, image = video.read()

            # Obs - problem for samme frame i flere id
            for id in segments:
                lesion_name = id['name'].replace(" ","")
                frames = id['seen']
                
                for value in frames:
                        start_frame = value[0]
                        end_frame = value[1]
                        
                        if start_frame <= int(count) <= end_frame:
                            # Saves the frames with frame-count
                            cv2.imwrite(path+file+"/%s_%d.jpg" % (lesion_name, count), image)
                            if verbose: print ("saved segment frame %d" % (count) )
            count += 1

# %%
def FrameCapture(path, file, type='findings', verbose=True): 
    
    video_name = file+'.mp4'
    findings, segments = get_findings_segments(path, file)
    
    # Make directory to store images
    try:
        os.mkdir(path+file)
    except OSError:
        if verbose: print ("Creation of the directory %s failed" % file)
    else:
        print ("Successfully created the directory %s " % file)
    
    # Path to video file 
    video = cv2.VideoCapture(path+video_name) 
    
    if type=='findings':
        save_findings(video, findings, path, file, verbose)
    else:
        save_segments(video, segments, path, file, verbose)

# %%
filename = "3ada4222967f421d"
path = "../data/"

FrameCapture(path, filename, 'findings', True)
# Out:
# Creation of the directory 3ada4222967f421d failed
# saved finding frame 2425 - pt1=(0, 184), pt2=(169, 333)
# saved finding frame 2426 - pt1=(0, 184), pt2=(179, 333)
# saved finding frame 2427 - pt1=(0, 134), pt2=(236, 333)
# saved finding frame 2428 - pt1=(0, 137), pt2=(236, 336)
# saved finding frame 2429 - pt1=(0, 152), pt2=(259, 336)
# saved finding frame 2430 - pt1=(1, 79), pt2=(163, 297)
# saved finding frame 2431 - pt1=(2, 8), pt2=(65, 199)
# saved finding frame 2432 - pt1=(3, 16), pt2=(45, 175)
# saved finding frame 2425 - pt1=(0, 184), pt2=(169, 333)
# saved finding frame 2426 - pt1=(0, 184), pt2=(179, 333)
# saved finding frame 2427 - pt1=(0, 134), pt2=(236, 333)
# saved finding frame 2428 - pt1=(0, 137), pt2=(236, 336)
# saved finding frame 2429 - pt1=(0, 152), pt2=(259, 336)
# saved finding frame 2430 - pt1=(1, 79), pt2=(163, 297)
# saved finding frame 2431 - pt1=(2, 8), pt2=(65, 199)
# saved finding frame 2432 - pt1=(3, 16), pt2=(45, 175)
# saved finding frame 2425 - pt1=(0, 184), pt2=(169, 333)
# saved finding frame 2426 - pt1=(0, 184), pt2=(179, 333)
# saved finding frame 2427 - pt1=(0, 134), pt2=(236, 333)
# saved finding frame 2428 - pt1=(0, 137), pt2=(236, 336)
# saved finding frame 2429 - pt1=(0, 152), pt2=(259, 336)
# saved finding frame 2430 - pt1=(1, 79), pt2=(163, 297)
# saved finding frame 2431 - pt1=(2, 8), pt2=(65, 199)
# saved finding frame 2432 - pt1=(3, 16), pt2=(45, 175)
# saved finding frame 2425 - pt1=(0, 184), pt2=(169, 333)
# saved finding frame 2426 - pt1=(0, 184), pt2=(179, 333)
# saved finding frame 2427 - pt1=(0, 134), pt2=(236, 333)
# saved finding frame 2428 - pt1=(0, 137), pt2=(236, 336)
# saved finding frame 2429 - pt1=(0, 152), pt2=(259, 336)
# saved finding frame 2430 - pt1=(1, 79), pt2=(163, 297)
# saved finding frame 2431 - pt1=(2, 8), pt2=(65, 199)
# saved finding frame 2432 - pt1=(3, 16), pt2=(45, 175)
# saved finding frame 2425 - pt1=(0, 184), pt2=(169, 333)
# saved finding frame 2426 - pt1=(0, 184), pt2=(179, 333)
# saved finding frame 2427 - pt1=(0, 134), pt2=(236, 333)
# saved finding frame 2428 - pt1=(0, 137), pt2=(236, 336)
# saved finding frame 2429 - pt1=(0, 152), pt2=(259, 336)
# saved finding frame 2430 - pt1=(1, 79), pt2=(163, 297)
# saved finding frame 2431 - pt1=(2, 8), pt2=(65, 199)
# saved finding frame 2432 - pt1=(3, 16), pt2=(45, 175)
# saved finding frame 2425 - pt1=(0, 184), pt2=(169, 333)
# saved finding frame 2426 - pt1=(0, 184), pt2=(179, 333)
# saved finding frame 2427 - pt1=(0, 134), pt2=(236, 333)
# saved finding frame 2428 - pt1=(0, 137), pt2=(236, 336)
# saved finding frame 2429 - pt1=(0, 152), pt2=(259, 336)
# saved finding frame 2430 - pt1=(1, 79), pt2=(163, 297)
# saved finding frame 2431 - pt1=(2, 8), pt2=(65, 199)
# saved finding frame 2432 - pt1=(3, 16), pt2=(45, 175)
# saved finding frame 2425 - pt1=(0, 184), pt2=(169, 333)
# saved finding frame 2426 - pt1=(0, 184), pt2=(179, 333)
# saved finding frame 2427 - pt1=(0, 134), pt2=(236, 333)
# saved finding frame 2428 - pt1=(0, 137), pt2=(236, 336)
# saved finding frame 2429 - pt1=(0, 152), pt2=(259, 336)
# saved finding frame 2430 - pt1=(1, 79), pt2=(163, 297)
# saved finding frame 2431 - pt1=(2, 8), pt2=(65, 199)
# saved finding frame 2432 - pt1=(3, 16), pt2=(45, 175)
# saved finding frame 2425 - pt1=(0, 184), pt2=(169, 333)
# saved finding frame 2426 - pt1=(0, 184), pt2=(179, 333)
# saved finding frame 2427 - pt1=(0, 134), pt2=(236, 333)
# saved finding frame 2428 - pt1=(0, 137), pt2=(236, 336)
# saved finding frame 2429 - pt1=(0, 152), pt2=(259, 336)
# saved finding frame 2430 - pt1=(1, 79), pt2=(163, 297)
# saved finding frame 2431 - pt1=(2, 8), pt2=(65, 199)
# saved finding frame 2432 - pt1=(3, 16), pt2=(45, 175)
# saved finding frame 7705 - pt1=(206, 12), pt2=(289, 96)
# saved finding frame 7706 - pt1=(208, 15), pt2=(290, 95)
# saved finding frame 7707 - pt1=(202, 5), pt2=(295, 95)
# saved finding frame 7708 - pt1=(198, 2), pt2=(295, 99)
# saved finding frame 7709 - pt1=(196, 2), pt2=(295, 101)
# saved finding frame 7710 - pt1=(194, 4), pt2=(297, 107)
# saved finding frame 7711 - pt1=(197, 4), pt2=(292, 100)
# saved finding frame 7712 - pt1=(199, 5), pt2=(292, 112)
# saved finding frame 7713 - pt1=(191, 5), pt2=(288, 110)
# saved finding frame 7714 - pt1=(193, 7), pt2=(293, 112)
# saved finding frame 7715 - pt1=(197, 5), pt2=(287, 111)
# saved finding frame 7716 - pt1=(201, 4), pt2=(282, 95)
# saved finding frame 7717 - pt1=(198, 6), pt2=(285, 112)
# saved finding frame 7718 - pt1=(194, 6), pt2=(288, 111)
# saved finding frame 7719 - pt1=(195, 4), pt2=(287, 110)
# saved finding frame 7720 - pt1=(196, 6), pt2=(290, 119)
# saved finding frame 7721 - pt1=(195, 6), pt2=(287, 123)
# saved finding frame 7722 - pt1=(197, 4), pt2=(281, 123)
# saved finding frame 7723 - pt1=(192, 2), pt2=(293, 124)
# saved finding frame 7724 - pt1=(199, 6), pt2=(290, 120)
# saved finding frame 7725 - pt1=(195, 10), pt2=(283, 122)
# saved finding frame 7726 - pt1=(193, 5), pt2=(294, 128)
# saved finding frame 7727 - pt1=(199, 4), pt2=(294, 112)
# saved finding frame 7728 - pt1=(196, 9), pt2=(284, 119)
# saved finding frame 7729 - pt1=(195, 7), pt2=(294, 120)
# saved finding frame 7730 - pt1=(194, 3), pt2=(297, 123)
# saved finding frame 7731 - pt1=(189, 3), pt2=(296, 112)
# saved finding frame 7732 - pt1=(193, 4), pt2=(299, 120)
# saved finding frame 7733 - pt1=(188, 2), pt2=(296, 113)
# saved finding frame 7734 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7735 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7736 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7737 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7738 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7739 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7740 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7741 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7742 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7743 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7744 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7745 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7746 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7747 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7748 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7749 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7750 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7751 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7752 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7753 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7754 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7755 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7756 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7757 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7758 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7759 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7760 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7761 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7705 - pt1=(206, 12), pt2=(289, 96)
# saved finding frame 7706 - pt1=(208, 15), pt2=(290, 95)
# saved finding frame 7707 - pt1=(202, 5), pt2=(295, 95)
# saved finding frame 7708 - pt1=(198, 2), pt2=(295, 99)
# saved finding frame 7709 - pt1=(196, 2), pt2=(295, 101)
# saved finding frame 7710 - pt1=(194, 4), pt2=(297, 107)
# saved finding frame 7711 - pt1=(197, 4), pt2=(292, 100)
# saved finding frame 7712 - pt1=(199, 5), pt2=(292, 112)
# saved finding frame 7713 - pt1=(191, 5), pt2=(288, 110)
# saved finding frame 7714 - pt1=(193, 7), pt2=(293, 112)
# saved finding frame 7715 - pt1=(197, 5), pt2=(287, 111)
# saved finding frame 7716 - pt1=(201, 4), pt2=(282, 95)
# saved finding frame 7717 - pt1=(198, 6), pt2=(285, 112)
# saved finding frame 7718 - pt1=(194, 6), pt2=(288, 111)
# saved finding frame 7719 - pt1=(195, 4), pt2=(287, 110)
# saved finding frame 7720 - pt1=(196, 6), pt2=(290, 119)
# saved finding frame 7721 - pt1=(195, 6), pt2=(287, 123)
# saved finding frame 7722 - pt1=(197, 4), pt2=(281, 123)
# saved finding frame 7723 - pt1=(192, 2), pt2=(293, 124)
# saved finding frame 7724 - pt1=(199, 6), pt2=(290, 120)
# saved finding frame 7725 - pt1=(195, 10), pt2=(283, 122)
# saved finding frame 7726 - pt1=(193, 5), pt2=(294, 128)
# saved finding frame 7727 - pt1=(199, 4), pt2=(294, 112)
# saved finding frame 7728 - pt1=(196, 9), pt2=(284, 119)
# saved finding frame 7729 - pt1=(195, 7), pt2=(294, 120)
# saved finding frame 7730 - pt1=(194, 3), pt2=(297, 123)
# saved finding frame 7731 - pt1=(189, 3), pt2=(296, 112)
# saved finding frame 7732 - pt1=(193, 4), pt2=(299, 120)
# saved finding frame 7733 - pt1=(188, 2), pt2=(296, 113)
# saved finding frame 7734 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7735 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7736 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7737 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7738 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7739 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7740 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7741 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7742 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7743 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7744 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7745 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7746 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7747 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7748 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7749 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7750 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7751 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7752 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7753 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7754 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7755 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7756 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7757 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7758 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7759 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7760 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7761 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7705 - pt1=(206, 12), pt2=(289, 96)
# saved finding frame 7706 - pt1=(208, 15), pt2=(290, 95)
# saved finding frame 7707 - pt1=(202, 5), pt2=(295, 95)
# saved finding frame 7708 - pt1=(198, 2), pt2=(295, 99)
# saved finding frame 7709 - pt1=(196, 2), pt2=(295, 101)
# saved finding frame 7710 - pt1=(194, 4), pt2=(297, 107)
# saved finding frame 7711 - pt1=(197, 4), pt2=(292, 100)
# saved finding frame 7712 - pt1=(199, 5), pt2=(292, 112)
# saved finding frame 7713 - pt1=(191, 5), pt2=(288, 110)
# saved finding frame 7714 - pt1=(193, 7), pt2=(293, 112)
# saved finding frame 7715 - pt1=(197, 5), pt2=(287, 111)
# saved finding frame 7716 - pt1=(201, 4), pt2=(282, 95)
# saved finding frame 7717 - pt1=(198, 6), pt2=(285, 112)
# saved finding frame 7718 - pt1=(194, 6), pt2=(288, 111)
# saved finding frame 7719 - pt1=(195, 4), pt2=(287, 110)
# saved finding frame 7720 - pt1=(196, 6), pt2=(290, 119)
# saved finding frame 7721 - pt1=(195, 6), pt2=(287, 123)
# saved finding frame 7722 - pt1=(197, 4), pt2=(281, 123)
# saved finding frame 7723 - pt1=(192, 2), pt2=(293, 124)
# saved finding frame 7724 - pt1=(199, 6), pt2=(290, 120)
# saved finding frame 7725 - pt1=(195, 10), pt2=(283, 122)
# saved finding frame 7726 - pt1=(193, 5), pt2=(294, 128)
# saved finding frame 7727 - pt1=(199, 4), pt2=(294, 112)
# saved finding frame 7728 - pt1=(196, 9), pt2=(284, 119)
# saved finding frame 7729 - pt1=(195, 7), pt2=(294, 120)
# saved finding frame 7730 - pt1=(194, 3), pt2=(297, 123)
# saved finding frame 7731 - pt1=(189, 3), pt2=(296, 112)
# saved finding frame 7732 - pt1=(193, 4), pt2=(299, 120)
# saved finding frame 7733 - pt1=(188, 2), pt2=(296, 113)
# saved finding frame 7734 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7735 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7736 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7737 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7738 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7739 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7740 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7741 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7742 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7743 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7744 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7745 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7746 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7747 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7748 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7749 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7750 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7751 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7752 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7753 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7754 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7755 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7756 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7757 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7758 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7759 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7760 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7761 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7705 - pt1=(206, 12), pt2=(289, 96)
# saved finding frame 7706 - pt1=(208, 15), pt2=(290, 95)
# saved finding frame 7707 - pt1=(202, 5), pt2=(295, 95)
# saved finding frame 7708 - pt1=(198, 2), pt2=(295, 99)
# saved finding frame 7709 - pt1=(196, 2), pt2=(295, 101)
# saved finding frame 7710 - pt1=(194, 4), pt2=(297, 107)
# saved finding frame 7711 - pt1=(197, 4), pt2=(292, 100)
# saved finding frame 7712 - pt1=(199, 5), pt2=(292, 112)
# saved finding frame 7713 - pt1=(191, 5), pt2=(288, 110)
# saved finding frame 7714 - pt1=(193, 7), pt2=(293, 112)
# saved finding frame 7715 - pt1=(197, 5), pt2=(287, 111)
# saved finding frame 7716 - pt1=(201, 4), pt2=(282, 95)
# saved finding frame 7717 - pt1=(198, 6), pt2=(285, 112)
# saved finding frame 7718 - pt1=(194, 6), pt2=(288, 111)
# saved finding frame 7719 - pt1=(195, 4), pt2=(287, 110)
# saved finding frame 7720 - pt1=(196, 6), pt2=(290, 119)
# saved finding frame 7721 - pt1=(195, 6), pt2=(287, 123)
# saved finding frame 7722 - pt1=(197, 4), pt2=(281, 123)
# saved finding frame 7723 - pt1=(192, 2), pt2=(293, 124)
# saved finding frame 7724 - pt1=(199, 6), pt2=(290, 120)
# saved finding frame 7725 - pt1=(195, 10), pt2=(283, 122)
# saved finding frame 7726 - pt1=(193, 5), pt2=(294, 128)
# saved finding frame 7727 - pt1=(199, 4), pt2=(294, 112)
# saved finding frame 7728 - pt1=(196, 9), pt2=(284, 119)
# saved finding frame 7729 - pt1=(195, 7), pt2=(294, 120)
# saved finding frame 7730 - pt1=(194, 3), pt2=(297, 123)
# saved finding frame 7731 - pt1=(189, 3), pt2=(296, 112)
# saved finding frame 7732 - pt1=(193, 4), pt2=(299, 120)
# saved finding frame 7733 - pt1=(188, 2), pt2=(296, 113)
# saved finding frame 7734 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7735 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7736 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7737 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7738 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7739 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7740 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7741 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7742 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7743 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7744 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7745 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7746 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7747 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7748 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7749 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7750 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7751 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7752 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7753 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7754 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7755 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7756 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7757 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7758 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7759 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7760 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7761 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7705 - pt1=(206, 12), pt2=(289, 96)
# saved finding frame 7706 - pt1=(208, 15), pt2=(290, 95)
# saved finding frame 7707 - pt1=(202, 5), pt2=(295, 95)
# saved finding frame 7708 - pt1=(198, 2), pt2=(295, 99)
# saved finding frame 7709 - pt1=(196, 2), pt2=(295, 101)
# saved finding frame 7710 - pt1=(194, 4), pt2=(297, 107)
# saved finding frame 7711 - pt1=(197, 4), pt2=(292, 100)
# saved finding frame 7712 - pt1=(199, 5), pt2=(292, 112)
# saved finding frame 7713 - pt1=(191, 5), pt2=(288, 110)
# saved finding frame 7714 - pt1=(193, 7), pt2=(293, 112)
# saved finding frame 7715 - pt1=(197, 5), pt2=(287, 111)
# saved finding frame 7716 - pt1=(201, 4), pt2=(282, 95)
# saved finding frame 7717 - pt1=(198, 6), pt2=(285, 112)
# saved finding frame 7718 - pt1=(194, 6), pt2=(288, 111)
# saved finding frame 7719 - pt1=(195, 4), pt2=(287, 110)
# saved finding frame 7720 - pt1=(196, 6), pt2=(290, 119)
# saved finding frame 7721 - pt1=(195, 6), pt2=(287, 123)
# saved finding frame 7722 - pt1=(197, 4), pt2=(281, 123)
# saved finding frame 7723 - pt1=(192, 2), pt2=(293, 124)
# saved finding frame 7724 - pt1=(199, 6), pt2=(290, 120)
# saved finding frame 7725 - pt1=(195, 10), pt2=(283, 122)
# saved finding frame 7726 - pt1=(193, 5), pt2=(294, 128)
# saved finding frame 7727 - pt1=(199, 4), pt2=(294, 112)
# saved finding frame 7728 - pt1=(196, 9), pt2=(284, 119)
# saved finding frame 7729 - pt1=(195, 7), pt2=(294, 120)
# saved finding frame 7730 - pt1=(194, 3), pt2=(297, 123)
# saved finding frame 7731 - pt1=(189, 3), pt2=(296, 112)
# saved finding frame 7732 - pt1=(193, 4), pt2=(299, 120)
# saved finding frame 7733 - pt1=(188, 2), pt2=(296, 113)
# saved finding frame 7734 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7735 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7736 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7737 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7738 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7739 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7740 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7741 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7742 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7743 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7744 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7745 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7746 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7747 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7748 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7749 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7750 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7751 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7752 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7753 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7754 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7755 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7756 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7757 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7758 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7759 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7760 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7761 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7705 - pt1=(206, 12), pt2=(289, 96)
# saved finding frame 7706 - pt1=(208, 15), pt2=(290, 95)
# saved finding frame 7707 - pt1=(202, 5), pt2=(295, 95)
# saved finding frame 7708 - pt1=(198, 2), pt2=(295, 99)
# saved finding frame 7709 - pt1=(196, 2), pt2=(295, 101)
# saved finding frame 7710 - pt1=(194, 4), pt2=(297, 107)
# saved finding frame 7711 - pt1=(197, 4), pt2=(292, 100)
# saved finding frame 7712 - pt1=(199, 5), pt2=(292, 112)
# saved finding frame 7713 - pt1=(191, 5), pt2=(288, 110)
# saved finding frame 7714 - pt1=(193, 7), pt2=(293, 112)
# saved finding frame 7715 - pt1=(197, 5), pt2=(287, 111)
# saved finding frame 7716 - pt1=(201, 4), pt2=(282, 95)
# saved finding frame 7717 - pt1=(198, 6), pt2=(285, 112)
# saved finding frame 7718 - pt1=(194, 6), pt2=(288, 111)
# saved finding frame 7719 - pt1=(195, 4), pt2=(287, 110)
# saved finding frame 7720 - pt1=(196, 6), pt2=(290, 119)
# saved finding frame 7721 - pt1=(195, 6), pt2=(287, 123)
# saved finding frame 7722 - pt1=(197, 4), pt2=(281, 123)
# saved finding frame 7723 - pt1=(192, 2), pt2=(293, 124)
# saved finding frame 7724 - pt1=(199, 6), pt2=(290, 120)
# saved finding frame 7725 - pt1=(195, 10), pt2=(283, 122)
# saved finding frame 7726 - pt1=(193, 5), pt2=(294, 128)
# saved finding frame 7727 - pt1=(199, 4), pt2=(294, 112)
# saved finding frame 7728 - pt1=(196, 9), pt2=(284, 119)
# saved finding frame 7729 - pt1=(195, 7), pt2=(294, 120)
# saved finding frame 7730 - pt1=(194, 3), pt2=(297, 123)
# saved finding frame 7731 - pt1=(189, 3), pt2=(296, 112)
# saved finding frame 7732 - pt1=(193, 4), pt2=(299, 120)
# saved finding frame 7733 - pt1=(188, 2), pt2=(296, 113)
# saved finding frame 7734 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7735 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7736 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7737 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7738 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7739 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7740 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7741 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7742 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7743 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7744 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7745 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7746 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7747 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7748 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7749 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7750 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7751 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7752 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7753 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7754 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7755 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7756 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7757 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7758 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7759 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7760 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7761 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7705 - pt1=(206, 12), pt2=(289, 96)
# saved finding frame 7706 - pt1=(208, 15), pt2=(290, 95)
# saved finding frame 7707 - pt1=(202, 5), pt2=(295, 95)
# saved finding frame 7708 - pt1=(198, 2), pt2=(295, 99)
# saved finding frame 7709 - pt1=(196, 2), pt2=(295, 101)
# saved finding frame 7710 - pt1=(194, 4), pt2=(297, 107)
# saved finding frame 7711 - pt1=(197, 4), pt2=(292, 100)
# saved finding frame 7712 - pt1=(199, 5), pt2=(292, 112)
# saved finding frame 7713 - pt1=(191, 5), pt2=(288, 110)
# saved finding frame 7714 - pt1=(193, 7), pt2=(293, 112)
# saved finding frame 7715 - pt1=(197, 5), pt2=(287, 111)
# saved finding frame 7716 - pt1=(201, 4), pt2=(282, 95)
# saved finding frame 7717 - pt1=(198, 6), pt2=(285, 112)
# saved finding frame 7718 - pt1=(194, 6), pt2=(288, 111)
# saved finding frame 7719 - pt1=(195, 4), pt2=(287, 110)
# saved finding frame 7720 - pt1=(196, 6), pt2=(290, 119)
# saved finding frame 7721 - pt1=(195, 6), pt2=(287, 123)
# saved finding frame 7722 - pt1=(197, 4), pt2=(281, 123)
# saved finding frame 7723 - pt1=(192, 2), pt2=(293, 124)
# saved finding frame 7724 - pt1=(199, 6), pt2=(290, 120)
# saved finding frame 7725 - pt1=(195, 10), pt2=(283, 122)
# saved finding frame 7726 - pt1=(193, 5), pt2=(294, 128)
# saved finding frame 7727 - pt1=(199, 4), pt2=(294, 112)
# saved finding frame 7728 - pt1=(196, 9), pt2=(284, 119)
# saved finding frame 7729 - pt1=(195, 7), pt2=(294, 120)
# saved finding frame 7730 - pt1=(194, 3), pt2=(297, 123)
# saved finding frame 7731 - pt1=(189, 3), pt2=(296, 112)
# saved finding frame 7732 - pt1=(193, 4), pt2=(299, 120)
# saved finding frame 7733 - pt1=(188, 2), pt2=(296, 113)
# saved finding frame 7734 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7735 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7736 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7737 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7738 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7739 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7740 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7741 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7742 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7743 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7744 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7745 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7746 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7747 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7748 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7749 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7750 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7751 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7752 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7753 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7754 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7755 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7756 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7757 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7758 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7759 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7760 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7761 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7705 - pt1=(206, 12), pt2=(289, 96)
# saved finding frame 7706 - pt1=(208, 15), pt2=(290, 95)
# saved finding frame 7707 - pt1=(202, 5), pt2=(295, 95)
# saved finding frame 7708 - pt1=(198, 2), pt2=(295, 99)
# saved finding frame 7709 - pt1=(196, 2), pt2=(295, 101)
# saved finding frame 7710 - pt1=(194, 4), pt2=(297, 107)
# saved finding frame 7711 - pt1=(197, 4), pt2=(292, 100)
# saved finding frame 7712 - pt1=(199, 5), pt2=(292, 112)
# saved finding frame 7713 - pt1=(191, 5), pt2=(288, 110)
# saved finding frame 7714 - pt1=(193, 7), pt2=(293, 112)
# saved finding frame 7715 - pt1=(197, 5), pt2=(287, 111)
# saved finding frame 7716 - pt1=(201, 4), pt2=(282, 95)
# saved finding frame 7717 - pt1=(198, 6), pt2=(285, 112)
# saved finding frame 7718 - pt1=(194, 6), pt2=(288, 111)
# saved finding frame 7719 - pt1=(195, 4), pt2=(287, 110)
# saved finding frame 7720 - pt1=(196, 6), pt2=(290, 119)
# saved finding frame 7721 - pt1=(195, 6), pt2=(287, 123)
# saved finding frame 7722 - pt1=(197, 4), pt2=(281, 123)
# saved finding frame 7723 - pt1=(192, 2), pt2=(293, 124)
# saved finding frame 7724 - pt1=(199, 6), pt2=(290, 120)
# saved finding frame 7725 - pt1=(195, 10), pt2=(283, 122)
# saved finding frame 7726 - pt1=(193, 5), pt2=(294, 128)
# saved finding frame 7727 - pt1=(199, 4), pt2=(294, 112)
# saved finding frame 7728 - pt1=(196, 9), pt2=(284, 119)
# saved finding frame 7729 - pt1=(195, 7), pt2=(294, 120)
# saved finding frame 7730 - pt1=(194, 3), pt2=(297, 123)
# saved finding frame 7731 - pt1=(189, 3), pt2=(296, 112)
# saved finding frame 7732 - pt1=(193, 4), pt2=(299, 120)
# saved finding frame 7733 - pt1=(188, 2), pt2=(296, 113)
# saved finding frame 7734 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7735 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7736 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7737 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7738 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7739 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7740 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7741 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7742 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7743 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7744 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7745 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7746 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7747 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7748 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7749 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7750 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7751 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7752 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7753 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7754 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7755 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7756 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7757 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7758 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7759 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7760 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7761 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7705 - pt1=(206, 12), pt2=(289, 96)
# saved finding frame 7706 - pt1=(208, 15), pt2=(290, 95)
# saved finding frame 7707 - pt1=(202, 5), pt2=(295, 95)
# saved finding frame 7708 - pt1=(198, 2), pt2=(295, 99)
# saved finding frame 7709 - pt1=(196, 2), pt2=(295, 101)
# saved finding frame 7710 - pt1=(194, 4), pt2=(297, 107)
# saved finding frame 7711 - pt1=(197, 4), pt2=(292, 100)
# saved finding frame 7712 - pt1=(199, 5), pt2=(292, 112)
# saved finding frame 7713 - pt1=(191, 5), pt2=(288, 110)
# saved finding frame 7714 - pt1=(193, 7), pt2=(293, 112)
# saved finding frame 7715 - pt1=(197, 5), pt2=(287, 111)
# saved finding frame 7716 - pt1=(201, 4), pt2=(282, 95)
# saved finding frame 7717 - pt1=(198, 6), pt2=(285, 112)
# saved finding frame 7718 - pt1=(194, 6), pt2=(288, 111)
# saved finding frame 7719 - pt1=(195, 4), pt2=(287, 110)
# saved finding frame 7720 - pt1=(196, 6), pt2=(290, 119)
# saved finding frame 7721 - pt1=(195, 6), pt2=(287, 123)
# saved finding frame 7722 - pt1=(197, 4), pt2=(281, 123)
# saved finding frame 7723 - pt1=(192, 2), pt2=(293, 124)
# saved finding frame 7724 - pt1=(199, 6), pt2=(290, 120)
# saved finding frame 7725 - pt1=(195, 10), pt2=(283, 122)
# saved finding frame 7726 - pt1=(193, 5), pt2=(294, 128)
# saved finding frame 7727 - pt1=(199, 4), pt2=(294, 112)
# saved finding frame 7728 - pt1=(196, 9), pt2=(284, 119)
# saved finding frame 7729 - pt1=(195, 7), pt2=(294, 120)
# saved finding frame 7730 - pt1=(194, 3), pt2=(297, 123)
# saved finding frame 7731 - pt1=(189, 3), pt2=(296, 112)
# saved finding frame 7732 - pt1=(193, 4), pt2=(299, 120)
# saved finding frame 7733 - pt1=(188, 2), pt2=(296, 113)
# saved finding frame 7734 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7735 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7736 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7737 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7738 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7739 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7740 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7741 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7742 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7743 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7744 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7745 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7746 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7747 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7748 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7749 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7750 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7751 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7752 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7753 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7754 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7755 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7756 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7757 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7758 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7759 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7760 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7761 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7705 - pt1=(206, 12), pt2=(289, 96)
# saved finding frame 7706 - pt1=(208, 15), pt2=(290, 95)
# saved finding frame 7707 - pt1=(202, 5), pt2=(295, 95)
# saved finding frame 7708 - pt1=(198, 2), pt2=(295, 99)
# saved finding frame 7709 - pt1=(196, 2), pt2=(295, 101)
# saved finding frame 7710 - pt1=(194, 4), pt2=(297, 107)
# saved finding frame 7711 - pt1=(197, 4), pt2=(292, 100)
# saved finding frame 7712 - pt1=(199, 5), pt2=(292, 112)
# saved finding frame 7713 - pt1=(191, 5), pt2=(288, 110)
# saved finding frame 7714 - pt1=(193, 7), pt2=(293, 112)
# saved finding frame 7715 - pt1=(197, 5), pt2=(287, 111)
# saved finding frame 7716 - pt1=(201, 4), pt2=(282, 95)
# saved finding frame 7717 - pt1=(198, 6), pt2=(285, 112)
# saved finding frame 7718 - pt1=(194, 6), pt2=(288, 111)
# saved finding frame 7719 - pt1=(195, 4), pt2=(287, 110)
# saved finding frame 7720 - pt1=(196, 6), pt2=(290, 119)
# saved finding frame 7721 - pt1=(195, 6), pt2=(287, 123)
# saved finding frame 7722 - pt1=(197, 4), pt2=(281, 123)
# saved finding frame 7723 - pt1=(192, 2), pt2=(293, 124)
# saved finding frame 7724 - pt1=(199, 6), pt2=(290, 120)
# saved finding frame 7725 - pt1=(195, 10), pt2=(283, 122)
# saved finding frame 7726 - pt1=(193, 5), pt2=(294, 128)
# saved finding frame 7727 - pt1=(199, 4), pt2=(294, 112)
# saved finding frame 7728 - pt1=(196, 9), pt2=(284, 119)
# saved finding frame 7729 - pt1=(195, 7), pt2=(294, 120)
# saved finding frame 7730 - pt1=(194, 3), pt2=(297, 123)
# saved finding frame 7731 - pt1=(189, 3), pt2=(296, 112)
# saved finding frame 7732 - pt1=(193, 4), pt2=(299, 120)
# saved finding frame 7733 - pt1=(188, 2), pt2=(296, 113)
# saved finding frame 7734 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7735 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7736 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7737 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7738 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7739 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7740 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7741 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7742 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7743 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7744 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7745 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7746 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7747 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7748 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7749 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7750 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7751 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7752 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7753 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7754 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7755 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7756 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7757 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7758 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7759 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7760 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7761 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7705 - pt1=(206, 12), pt2=(289, 96)
# saved finding frame 7706 - pt1=(208, 15), pt2=(290, 95)
# saved finding frame 7707 - pt1=(202, 5), pt2=(295, 95)
# saved finding frame 7708 - pt1=(198, 2), pt2=(295, 99)
# saved finding frame 7709 - pt1=(196, 2), pt2=(295, 101)
# saved finding frame 7710 - pt1=(194, 4), pt2=(297, 107)
# saved finding frame 7711 - pt1=(197, 4), pt2=(292, 100)
# saved finding frame 7712 - pt1=(199, 5), pt2=(292, 112)
# saved finding frame 7713 - pt1=(191, 5), pt2=(288, 110)
# saved finding frame 7714 - pt1=(193, 7), pt2=(293, 112)
# saved finding frame 7715 - pt1=(197, 5), pt2=(287, 111)
# saved finding frame 7716 - pt1=(201, 4), pt2=(282, 95)
# saved finding frame 7717 - pt1=(198, 6), pt2=(285, 112)
# saved finding frame 7718 - pt1=(194, 6), pt2=(288, 111)
# saved finding frame 7719 - pt1=(195, 4), pt2=(287, 110)
# saved finding frame 7720 - pt1=(196, 6), pt2=(290, 119)
# saved finding frame 7721 - pt1=(195, 6), pt2=(287, 123)
# saved finding frame 7722 - pt1=(197, 4), pt2=(281, 123)
# saved finding frame 7723 - pt1=(192, 2), pt2=(293, 124)
# saved finding frame 7724 - pt1=(199, 6), pt2=(290, 120)
# saved finding frame 7725 - pt1=(195, 10), pt2=(283, 122)
# saved finding frame 7726 - pt1=(193, 5), pt2=(294, 128)
# saved finding frame 7727 - pt1=(199, 4), pt2=(294, 112)
# saved finding frame 7728 - pt1=(196, 9), pt2=(284, 119)
# saved finding frame 7729 - pt1=(195, 7), pt2=(294, 120)
# saved finding frame 7730 - pt1=(194, 3), pt2=(297, 123)
# saved finding frame 7731 - pt1=(189, 3), pt2=(296, 112)
# saved finding frame 7732 - pt1=(193, 4), pt2=(299, 120)
# saved finding frame 7733 - pt1=(188, 2), pt2=(296, 113)
# saved finding frame 7734 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7735 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7736 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7737 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7738 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7739 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7740 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7741 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7742 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7743 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7744 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7745 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7746 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7747 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7748 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7749 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7750 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7751 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7752 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7753 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7754 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7755 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7756 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7757 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7758 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7759 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7760 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7761 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7705 - pt1=(206, 12), pt2=(289, 96)
# saved finding frame 7706 - pt1=(208, 15), pt2=(290, 95)
# saved finding frame 7707 - pt1=(202, 5), pt2=(295, 95)
# saved finding frame 7708 - pt1=(198, 2), pt2=(295, 99)
# saved finding frame 7709 - pt1=(196, 2), pt2=(295, 101)
# saved finding frame 7710 - pt1=(194, 4), pt2=(297, 107)
# saved finding frame 7711 - pt1=(197, 4), pt2=(292, 100)
# saved finding frame 7712 - pt1=(199, 5), pt2=(292, 112)
# saved finding frame 7713 - pt1=(191, 5), pt2=(288, 110)
# saved finding frame 7714 - pt1=(193, 7), pt2=(293, 112)
# saved finding frame 7715 - pt1=(197, 5), pt2=(287, 111)
# saved finding frame 7716 - pt1=(201, 4), pt2=(282, 95)
# saved finding frame 7717 - pt1=(198, 6), pt2=(285, 112)
# saved finding frame 7718 - pt1=(194, 6), pt2=(288, 111)
# saved finding frame 7719 - pt1=(195, 4), pt2=(287, 110)
# saved finding frame 7720 - pt1=(196, 6), pt2=(290, 119)
# saved finding frame 7721 - pt1=(195, 6), pt2=(287, 123)
# saved finding frame 7722 - pt1=(197, 4), pt2=(281, 123)
# saved finding frame 7723 - pt1=(192, 2), pt2=(293, 124)
# saved finding frame 7724 - pt1=(199, 6), pt2=(290, 120)
# saved finding frame 7725 - pt1=(195, 10), pt2=(283, 122)
# saved finding frame 7726 - pt1=(193, 5), pt2=(294, 128)
# saved finding frame 7727 - pt1=(199, 4), pt2=(294, 112)
# saved finding frame 7728 - pt1=(196, 9), pt2=(284, 119)
# saved finding frame 7729 - pt1=(195, 7), pt2=(294, 120)
# saved finding frame 7730 - pt1=(194, 3), pt2=(297, 123)
# saved finding frame 7731 - pt1=(189, 3), pt2=(296, 112)
# saved finding frame 7732 - pt1=(193, 4), pt2=(299, 120)
# saved finding frame 7733 - pt1=(188, 2), pt2=(296, 113)
# saved finding frame 7734 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7735 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7736 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7737 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7738 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7739 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7740 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7741 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7742 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7743 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7744 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7745 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7746 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7747 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7748 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7749 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7750 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7751 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7752 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7753 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7754 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7755 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7756 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7757 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7758 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7759 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7760 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7761 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7705 - pt1=(206, 12), pt2=(289, 96)
# saved finding frame 7706 - pt1=(208, 15), pt2=(290, 95)
# saved finding frame 7707 - pt1=(202, 5), pt2=(295, 95)
# saved finding frame 7708 - pt1=(198, 2), pt2=(295, 99)
# saved finding frame 7709 - pt1=(196, 2), pt2=(295, 101)
# saved finding frame 7710 - pt1=(194, 4), pt2=(297, 107)
# saved finding frame 7711 - pt1=(197, 4), pt2=(292, 100)
# saved finding frame 7712 - pt1=(199, 5), pt2=(292, 112)
# saved finding frame 7713 - pt1=(191, 5), pt2=(288, 110)
# saved finding frame 7714 - pt1=(193, 7), pt2=(293, 112)
# saved finding frame 7715 - pt1=(197, 5), pt2=(287, 111)
# saved finding frame 7716 - pt1=(201, 4), pt2=(282, 95)
# saved finding frame 7717 - pt1=(198, 6), pt2=(285, 112)
# saved finding frame 7718 - pt1=(194, 6), pt2=(288, 111)
# saved finding frame 7719 - pt1=(195, 4), pt2=(287, 110)
# saved finding frame 7720 - pt1=(196, 6), pt2=(290, 119)
# saved finding frame 7721 - pt1=(195, 6), pt2=(287, 123)
# saved finding frame 7722 - pt1=(197, 4), pt2=(281, 123)
# saved finding frame 7723 - pt1=(192, 2), pt2=(293, 124)
# saved finding frame 7724 - pt1=(199, 6), pt2=(290, 120)
# saved finding frame 7725 - pt1=(195, 10), pt2=(283, 122)
# saved finding frame 7726 - pt1=(193, 5), pt2=(294, 128)
# saved finding frame 7727 - pt1=(199, 4), pt2=(294, 112)
# saved finding frame 7728 - pt1=(196, 9), pt2=(284, 119)
# saved finding frame 7729 - pt1=(195, 7), pt2=(294, 120)
# saved finding frame 7730 - pt1=(194, 3), pt2=(297, 123)
# saved finding frame 7731 - pt1=(189, 3), pt2=(296, 112)
# saved finding frame 7732 - pt1=(193, 4), pt2=(299, 120)
# saved finding frame 7733 - pt1=(188, 2), pt2=(296, 113)
# saved finding frame 7734 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7735 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7736 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7737 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7738 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7739 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7740 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7741 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7742 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7743 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7744 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7745 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7746 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7747 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7748 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7749 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7750 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7751 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7752 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7753 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7754 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7755 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7756 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7757 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7758 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7759 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7760 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7761 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7705 - pt1=(206, 12), pt2=(289, 96)
# saved finding frame 7706 - pt1=(208, 15), pt2=(290, 95)
# saved finding frame 7707 - pt1=(202, 5), pt2=(295, 95)
# saved finding frame 7708 - pt1=(198, 2), pt2=(295, 99)
# saved finding frame 7709 - pt1=(196, 2), pt2=(295, 101)
# saved finding frame 7710 - pt1=(194, 4), pt2=(297, 107)
# saved finding frame 7711 - pt1=(197, 4), pt2=(292, 100)
# saved finding frame 7712 - pt1=(199, 5), pt2=(292, 112)
# saved finding frame 7713 - pt1=(191, 5), pt2=(288, 110)
# saved finding frame 7714 - pt1=(193, 7), pt2=(293, 112)
# saved finding frame 7715 - pt1=(197, 5), pt2=(287, 111)
# saved finding frame 7716 - pt1=(201, 4), pt2=(282, 95)
# saved finding frame 7717 - pt1=(198, 6), pt2=(285, 112)
# saved finding frame 7718 - pt1=(194, 6), pt2=(288, 111)
# saved finding frame 7719 - pt1=(195, 4), pt2=(287, 110)
# saved finding frame 7720 - pt1=(196, 6), pt2=(290, 119)
# saved finding frame 7721 - pt1=(195, 6), pt2=(287, 123)
# saved finding frame 7722 - pt1=(197, 4), pt2=(281, 123)
# saved finding frame 7723 - pt1=(192, 2), pt2=(293, 124)
# saved finding frame 7724 - pt1=(199, 6), pt2=(290, 120)
# saved finding frame 7725 - pt1=(195, 10), pt2=(283, 122)
# saved finding frame 7726 - pt1=(193, 5), pt2=(294, 128)
# saved finding frame 7727 - pt1=(199, 4), pt2=(294, 112)
# saved finding frame 7728 - pt1=(196, 9), pt2=(284, 119)
# saved finding frame 7729 - pt1=(195, 7), pt2=(294, 120)
# saved finding frame 7730 - pt1=(194, 3), pt2=(297, 123)
# saved finding frame 7731 - pt1=(189, 3), pt2=(296, 112)
# saved finding frame 7732 - pt1=(193, 4), pt2=(299, 120)
# saved finding frame 7733 - pt1=(188, 2), pt2=(296, 113)
# saved finding frame 7734 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7735 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7736 - pt1=(190, 2), pt2=(273, 110)
# saved finding frame 7737 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7738 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7739 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7740 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7741 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7742 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7743 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7744 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7745 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7746 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7747 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7748 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7749 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7750 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7751 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7752 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7753 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7754 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7755 - pt1=(202, 2), pt2=(286, 110)
# saved finding frame 7756 - pt1=(202, 2), pt2=(286, 110)
# ...
# saved finding frame 11566 - pt1=(254, 43), pt2=(331, 273)
# saved finding frame 11567 - pt1=(260, 57), pt2=(333, 260)
# saved finding frame 11568 - pt1=(258, 56), pt2=(332, 281)
# saved finding frame 11551 - pt1=(264, 21), pt2=(336, 282)
# saved finding frame 11552 - pt1=(257, 29), pt2=(333, 271)
# saved finding frame 11553 - pt1=(248, 32), pt2=(336, 262)
# saved finding frame 11554 - pt1=(246, 41), pt2=(332, 258)
# saved finding frame 11555 - pt1=(238, 29), pt2=(330, 248)
# saved finding frame 11556 - pt1=(250, 34), pt2=(331, 264)
# saved finding frame 11557 - pt1=(250, 33), pt2=(329, 267)
# saved finding frame 11558 - pt1=(245, 38), pt2=(327, 263)
# saved finding frame 11559 - pt1=(251, 40), pt2=(328, 260)
# saved finding frame 11560 - pt1=(255, 30), pt2=(342, 266)
# saved finding frame 11561 - pt1=(268, 41), pt2=(337, 274)
# saved finding frame 11563 - pt1=(266, 44), pt2=(330, 293)
# saved finding frame 11564 - pt1=(253, 38), pt2=(335, 276)
# saved finding frame 11565 - pt1=(253, 45), pt2=(332, 274)
# saved finding frame 11566 - pt1=(254, 43), pt2=(331, 273)
# saved finding frame 11567 - pt1=(260, 57), pt2=(333, 260)
# saved finding frame 11568 - pt1=(258, 56), pt2=(332, 281)
# saved finding frame 11551 - pt1=(264, 21), pt2=(336, 282)
# saved finding frame 11552 - pt1=(257, 29), pt2=(333, 271)
# saved finding frame 11553 - pt1=(248, 32), pt2=(336, 262)
# saved finding frame 11554 - pt1=(246, 41), pt2=(332, 258)
# saved finding frame 11555 - pt1=(238, 29), pt2=(330, 248)
# saved finding frame 11556 - pt1=(250, 34), pt2=(331, 264)
# saved finding frame 11557 - pt1=(250, 33), pt2=(329, 267)
# saved finding frame 11558 - pt1=(245, 38), pt2=(327, 263)
# saved finding frame 11559 - pt1=(251, 40), pt2=(328, 260)
# saved finding frame 11560 - pt1=(255, 30), pt2=(342, 266)
# saved finding frame 11561 - pt1=(268, 41), pt2=(337, 274)
# saved finding frame 11563 - pt1=(266, 44), pt2=(330, 293)
# saved finding frame 11564 - pt1=(253, 38), pt2=(335, 276)
# saved finding frame 11565 - pt1=(253, 45), pt2=(332, 274)
# saved finding frame 11566 - pt1=(254, 43), pt2=(331, 273)
# saved finding frame 11567 - pt1=(260, 57), pt2=(333, 260)
# saved finding frame 11568 - pt1=(258, 56), pt2=(332, 281)
# saved finding frame 11551 - pt1=(264, 21), pt2=(336, 282)
# saved finding frame 11552 - pt1=(257, 29), pt2=(333, 271)
# saved finding frame 11553 - pt1=(248, 32), pt2=(336, 262)
# saved finding frame 11554 - pt1=(246, 41), pt2=(332, 258)
# saved finding frame 11555 - pt1=(238, 29), pt2=(330, 248)
# saved finding frame 11556 - pt1=(250, 34), pt2=(331, 264)
# saved finding frame 11557 - pt1=(250, 33), pt2=(329, 267)
# saved finding frame 11558 - pt1=(245, 38), pt2=(327, 263)
# saved finding frame 11559 - pt1=(251, 40), pt2=(328, 260)
# saved finding frame 11560 - pt1=(255, 30), pt2=(342, 266)
# saved finding frame 11561 - pt1=(268, 41), pt2=(337, 274)
# saved finding frame 11563 - pt1=(266, 44), pt2=(330, 293)
# saved finding frame 11564 - pt1=(253, 38), pt2=(335, 276)
# saved finding frame 11565 - pt1=(253, 45), pt2=(332, 274)
# saved finding frame 11566 - pt1=(254, 43), pt2=(331, 273)
# saved finding frame 11567 - pt1=(260, 57), pt2=(333, 260)
# saved finding frame 11568 - pt1=(258, 56), pt2=(332, 281)
# saved finding frame 11551 - pt1=(264, 21), pt2=(336, 282)
# saved finding frame 11552 - pt1=(257, 29), pt2=(333, 271)
# saved finding frame 11553 - pt1=(248, 32), pt2=(336, 262)
# saved finding frame 11554 - pt1=(246, 41), pt2=(332, 258)
# saved finding frame 11555 - pt1=(238, 29), pt2=(330, 248)
# saved finding frame 11556 - pt1=(250, 34), pt2=(331, 264)
# saved finding frame 11557 - pt1=(250, 33), pt2=(329, 267)
# saved finding frame 11558 - pt1=(245, 38), pt2=(327, 263)
# saved finding frame 11559 - pt1=(251, 40), pt2=(328, 260)
# saved finding frame 11560 - pt1=(255, 30), pt2=(342, 266)
# saved finding frame 11561 - pt1=(268, 41), pt2=(337, 274)
# saved finding frame 11563 - pt1=(266, 44), pt2=(330, 293)
# saved finding frame 11564 - pt1=(253, 38), pt2=(335, 276)
# saved finding frame 11565 - pt1=(253, 45), pt2=(332, 274)
# saved finding frame 11566 - pt1=(254, 43), pt2=(331, 273)
# saved finding frame 11567 - pt1=(260, 57), pt2=(333, 260)
# saved finding frame 11568 - pt1=(258, 56), pt2=(332, 281)
# saved finding frame 11551 - pt1=(264, 21), pt2=(336, 282)
# saved finding frame 11552 - pt1=(257, 29), pt2=(333, 271)
# saved finding frame 11553 - pt1=(248, 32), pt2=(336, 262)
# saved finding frame 11554 - pt1=(246, 41), pt2=(332, 258)
# saved finding frame 11555 - pt1=(238, 29), pt2=(330, 248)
# saved finding frame 11556 - pt1=(250, 34), pt2=(331, 264)
# saved finding frame 11557 - pt1=(250, 33), pt2=(329, 267)
# saved finding frame 11558 - pt1=(245, 38), pt2=(327, 263)
# saved finding frame 11559 - pt1=(251, 40), pt2=(328, 260)
# saved finding frame 11560 - pt1=(255, 30), pt2=(342, 266)
# saved finding frame 11561 - pt1=(268, 41), pt2=(337, 274)
# saved finding frame 11563 - pt1=(266, 44), pt2=(330, 293)
# saved finding frame 11564 - pt1=(253, 38), pt2=(335, 276)
# saved finding frame 11565 - pt1=(253, 45), pt2=(332, 274)
# saved finding frame 11566 - pt1=(254, 43), pt2=(331, 273)
# saved finding frame 11567 - pt1=(260, 57), pt2=(333, 260)
# saved finding frame 11568 - pt1=(258, 56), pt2=(332, 281)
# saved finding frame 11551 - pt1=(264, 21), pt2=(336, 282)
# saved finding frame 11552 - pt1=(257, 29), pt2=(333, 271)
# saved finding frame 11553 - pt1=(248, 32), pt2=(336, 262)
# saved finding frame 11554 - pt1=(246, 41), pt2=(332, 258)
# saved finding frame 11555 - pt1=(238, 29), pt2=(330, 248)
# saved finding frame 11556 - pt1=(250, 34), pt2=(331, 264)
# saved finding frame 11557 - pt1=(250, 33), pt2=(329, 267)
# saved finding frame 11558 - pt1=(245, 38), pt2=(327, 263)
# saved finding frame 11559 - pt1=(251, 40), pt2=(328, 260)
# saved finding frame 11560 - pt1=(255, 30), pt2=(342, 266)
# saved finding frame 11561 - pt1=(268, 41), pt2=(337, 274)
# saved finding frame 11563 - pt1=(266, 44), pt2=(330, 293)
# saved finding frame 11564 - pt1=(253, 38), pt2=(335, 276)
# saved finding frame 11565 - pt1=(253, 45), pt2=(332, 274)
# saved finding frame 11566 - pt1=(254, 43), pt2=(331, 273)
# saved finding frame 11567 - pt1=(260, 57), pt2=(333, 260)
# saved finding frame 11568 - pt1=(258, 56), pt2=(332, 281)
# saved finding frame 11551 - pt1=(264, 21), pt2=(336, 282)
# saved finding frame 11552 - pt1=(257, 29), pt2=(333, 271)
# saved finding frame 11553 - pt1=(248, 32), pt2=(336, 262)
# saved finding frame 11554 - pt1=(246, 41), pt2=(332, 258)
# saved finding frame 11555 - pt1=(238, 29), pt2=(330, 248)
# saved finding frame 11556 - pt1=(250, 34), pt2=(331, 264)
# saved finding frame 11557 - pt1=(250, 33), pt2=(329, 267)
# saved finding frame 11558 - pt1=(245, 38), pt2=(327, 263)
# saved finding frame 11559 - pt1=(251, 40), pt2=(328, 260)
# saved finding frame 11560 - pt1=(255, 30), pt2=(342, 266)
# saved finding frame 11561 - pt1=(268, 41), pt2=(337, 274)
# saved finding frame 11563 - pt1=(266, 44), pt2=(330, 293)
# saved finding frame 11564 - pt1=(253, 38), pt2=(335, 276)
# saved finding frame 11565 - pt1=(253, 45), pt2=(332, 274)
# saved finding frame 11566 - pt1=(254, 43), pt2=(331, 273)
# saved finding frame 11567 - pt1=(260, 57), pt2=(333, 260)
# saved finding frame 11568 - pt1=(258, 56), pt2=(332, 281)
# saved finding frame 11551 - pt1=(264, 21), pt2=(336, 282)
# saved finding frame 11552 - pt1=(257, 29), pt2=(333, 271)
# saved finding frame 11553 - pt1=(248, 32), pt2=(336, 262)
# saved finding frame 11554 - pt1=(246, 41), pt2=(332, 258)
# saved finding frame 11555 - pt1=(238, 29), pt2=(330, 248)
# saved finding frame 11556 - pt1=(250, 34), pt2=(331, 264)
# saved finding frame 11557 - pt1=(250, 33), pt2=(329, 267)
# saved finding frame 11558 - pt1=(245, 38), pt2=(327, 263)
# saved finding frame 11559 - pt1=(251, 40), pt2=(328, 260)
# saved finding frame 11560 - pt1=(255, 30), pt2=(342, 266)
# saved finding frame 11561 - pt1=(268, 41), pt2=(337, 274)
# saved finding frame 11563 - pt1=(266, 44), pt2=(330, 293)
# saved finding frame 11564 - pt1=(253, 38), pt2=(335, 276)
# saved finding frame 11565 - pt1=(253, 45), pt2=(332, 274)
# saved finding frame 11566 - pt1=(254, 43), pt2=(331, 273)
# saved finding frame 11567 - pt1=(260, 57), pt2=(333, 260)
# saved finding frame 11568 - pt1=(258, 56), pt2=(332, 281)
# saved finding frame 11551 - pt1=(264, 21), pt2=(336, 282)
# saved finding frame 11552 - pt1=(257, 29), pt2=(333, 271)
# saved finding frame 11553 - pt1=(248, 32), pt2=(336, 262)
# saved finding frame 11554 - pt1=(246, 41), pt2=(332, 258)
# saved finding frame 11555 - pt1=(238, 29), pt2=(330, 248)
# saved finding frame 11556 - pt1=(250, 34), pt2=(331, 264)
# saved finding frame 11557 - pt1=(250, 33), pt2=(329, 267)
# saved finding frame 11558 - pt1=(245, 38), pt2=(327, 263)
# saved finding frame 11559 - pt1=(251, 40), pt2=(328, 260)
# saved finding frame 11560 - pt1=(255, 30), pt2=(342, 266)
# saved finding frame 11561 - pt1=(268, 41), pt2=(337, 274)
# saved finding frame 11563 - pt1=(266, 44), pt2=(330, 293)
# saved finding frame 11564 - pt1=(253, 38), pt2=(335, 276)
# saved finding frame 11565 - pt1=(253, 45), pt2=(332, 274)
# saved finding frame 11566 - pt1=(254, 43), pt2=(331, 273)
# saved finding frame 11567 - pt1=(260, 57), pt2=(333, 260)
# saved finding frame 11568 - pt1=(258, 56), pt2=(332, 281)
# saved finding frame 11551 - pt1=(264, 21), pt2=(336, 282)
# saved finding frame 11552 - pt1=(257, 29), pt2=(333, 271)
# saved finding frame 11553 - pt1=(248, 32), pt2=(336, 262)
# saved finding frame 11554 - pt1=(246, 41), pt2=(332, 258)
# saved finding frame 11555 - pt1=(238, 29), pt2=(330, 248)
# saved finding frame 11556 - pt1=(250, 34), pt2=(331, 264)
# saved finding frame 11557 - pt1=(250, 33), pt2=(329, 267)
# saved finding frame 11558 - pt1=(245, 38), pt2=(327, 263)
# saved finding frame 11559 - pt1=(251, 40), pt2=(328, 260)
# saved finding frame 11560 - pt1=(255, 30), pt2=(342, 266)
# saved finding frame 11561 - pt1=(268, 41), pt2=(337, 274)
# saved finding frame 11563 - pt1=(266, 44), pt2=(330, 293)
# saved finding frame 11564 - pt1=(253, 38), pt2=(335, 276)
# saved finding frame 11565 - pt1=(253, 45), pt2=(332, 274)
# saved finding frame 11566 - pt1=(254, 43), pt2=(331, 273)
# saved finding frame 11567 - pt1=(260, 57), pt2=(333, 260)
# saved finding frame 11568 - pt1=(258, 56), pt2=(332, 281)
# saved finding frame 11551 - pt1=(264, 21), pt2=(336, 282)
# saved finding frame 11552 - pt1=(257, 29), pt2=(333, 271)
# saved finding frame 11553 - pt1=(248, 32), pt2=(336, 262)
# saved finding frame 11554 - pt1=(246, 41), pt2=(332, 258)
# saved finding frame 11555 - pt1=(238, 29), pt2=(330, 248)
# saved finding frame 11556 - pt1=(250, 34), pt2=(331, 264)
# saved finding frame 11557 - pt1=(250, 33), pt2=(329, 267)
# saved finding frame 11558 - pt1=(245, 38), pt2=(327, 263)
# saved finding frame 11559 - pt1=(251, 40), pt2=(328, 260)
# saved finding frame 11560 - pt1=(255, 30), pt2=(342, 266)
# saved finding frame 11561 - pt1=(268, 41), pt2=(337, 274)
# saved finding frame 11563 - pt1=(266, 44), pt2=(330, 293)
# saved finding frame 11564 - pt1=(253, 38), pt2=(335, 276)
# saved finding frame 11565 - pt1=(253, 45), pt2=(332, 274)
# saved finding frame 11566 - pt1=(254, 43), pt2=(331, 273)
# saved finding frame 11567 - pt1=(260, 57), pt2=(333, 260)
# saved finding frame 11568 - pt1=(258, 56), pt2=(332, 281)
# saved finding frame 11551 - pt1=(264, 21), pt2=(336, 282)
# saved finding frame 11552 - pt1=(257, 29), pt2=(333, 271)
# saved finding frame 11553 - pt1=(248, 32), pt2=(336, 262)
# saved finding frame 11554 - pt1=(246, 41), pt2=(332, 258)
# saved finding frame 11555 - pt1=(238, 29), pt2=(330, 248)
# saved finding frame 11556 - pt1=(250, 34), pt2=(331, 264)
# saved finding frame 11557 - pt1=(250, 33), pt2=(329, 267)
# saved finding frame 11558 - pt1=(245, 38), pt2=(327, 263)
# saved finding frame 11559 - pt1=(251, 40), pt2=(328, 260)
# saved finding frame 11560 - pt1=(255, 30), pt2=(342, 266)
# saved finding frame 11561 - pt1=(268, 41), pt2=(337, 274)
# saved finding frame 11563 - pt1=(266, 44), pt2=(330, 293)
# saved finding frame 11564 - pt1=(253, 38), pt2=(335, 276)
# saved finding frame 11565 - pt1=(253, 45), pt2=(332, 274)
# saved finding frame 11566 - pt1=(254, 43), pt2=(331, 273)
# saved finding frame 11567 - pt1=(260, 57), pt2=(333, 260)
# saved finding frame 11568 - pt1=(258, 56), pt2=(332, 281)
# saved finding frame 11551 - pt1=(264, 21), pt2=(336, 282)
# saved finding frame 11552 - pt1=(257, 29), pt2=(333, 271)
# saved finding frame 11553 - pt1=(248, 32), pt2=(336, 262)
# saved finding frame 11554 - pt1=(246, 41), pt2=(332, 258)
# saved finding frame 11555 - pt1=(238, 29), pt2=(330, 248)
# saved finding frame 11556 - pt1=(250, 34), pt2=(331, 264)
# saved finding frame 11557 - pt1=(250, 33), pt2=(329, 267)
# saved finding frame 11558 - pt1=(245, 38), pt2=(327, 263)
# saved finding frame 11559 - pt1=(251, 40), pt2=(328, 260)
# saved finding frame 11560 - pt1=(255, 30), pt2=(342, 266)
# saved finding frame 11561 - pt1=(268, 41), pt2=(337, 274)
# saved finding frame 11563 - pt1=(266, 44), pt2=(330, 293)
# saved finding frame 11564 - pt1=(253, 38), pt2=(335, 276)
# saved finding frame 11565 - pt1=(253, 45), pt2=(332, 274)
# saved finding frame 11566 - pt1=(254, 43), pt2=(331, 273)
# saved finding frame 11567 - pt1=(260, 57), pt2=(333, 260)
# saved finding frame 11568 - pt1=(258, 56), pt2=(332, 281)
# saved finding frame 11551 - pt1=(264, 21), pt2=(336, 282)
# saved finding frame 11552 - pt1=(257, 29), pt2=(333, 271)
# saved finding frame 11553 - pt1=(248, 32), pt2=(336, 262)
# saved finding frame 11554 - pt1=(246, 41), pt2=(332, 258)
# saved finding frame 11555 - pt1=(238, 29), pt2=(330, 248)
# saved finding frame 11556 - pt1=(250, 34), pt2=(331, 264)
# saved finding frame 11557 - pt1=(250, 33), pt2=(329, 267)
# saved finding frame 11558 - pt1=(245, 38), pt2=(327, 263)
# saved finding frame 11559 - pt1=(251, 40), pt2=(328, 260)
# saved finding frame 11560 - pt1=(255, 30), pt2=(342, 266)
# saved finding frame 11561 - pt1=(268, 41), pt2=(337, 274)
# saved finding frame 11563 - pt1=(266, 44), pt2=(330, 293)
# saved finding frame 11564 - pt1=(253, 38), pt2=(335, 276)
# saved finding frame 11565 - pt1=(253, 45), pt2=(332, 274)
# saved finding frame 11566 - pt1=(254, 43), pt2=(331, 273)
# saved finding frame 11567 - pt1=(260, 57), pt2=(333, 260)
# saved finding frame 11568 - pt1=(258, 56), pt2=(332, 281)
# saved finding frame 11551 - pt1=(264, 21), pt2=(336, 282)
# saved finding frame 11552 - pt1=(257, 29), pt2=(333, 271)
# saved finding frame 11553 - pt1=(248, 32), pt2=(336, 262)
# saved finding frame 11554 - pt1=(246, 41), pt2=(332, 258)
# saved finding frame 11555 - pt1=(238, 29), pt2=(330, 248)
# saved finding frame 11556 - pt1=(250, 34), pt2=(331, 264)
# saved finding frame 11557 - pt1=(250, 33), pt2=(329, 267)
# saved finding frame 11558 - pt1=(245, 38), pt2=(327, 263)
# saved finding frame 11559 - pt1=(251, 40), pt2=(328, 260)
# saved finding frame 11560 - pt1=(255, 30), pt2=(342, 266)
# saved finding frame 11561 - pt1=(268, 41), pt2=(337, 274)
# saved finding frame 11563 - pt1=(266, 44), pt2=(330, 293)
# saved finding frame 11564 - pt1=(253, 38), pt2=(335, 276)
# saved finding frame 11565 - pt1=(253, 45), pt2=(332, 274)
# saved finding frame 11566 - pt1=(254, 43), pt2=(331, 273)
# saved finding frame 11567 - pt1=(260, 57), pt2=(333, 260)
# saved finding frame 11568 - pt1=(258, 56), pt2=(332, 281)
# saved finding frame 11551 - pt1=(264, 21), pt2=(336, 282)
# saved finding frame 11552 - pt1=(257, 29), pt2=(333, 271)
# saved finding frame 11553 - pt1=(248, 32), pt2=(336, 262)
# saved finding frame 11554 - pt1=(246, 41), pt2=(332, 258)
# saved finding frame 11555 - pt1=(238, 29), pt2=(330, 248)
# saved finding frame 11556 - pt1=(250, 34), pt2=(331, 264)
# saved finding frame 11557 - pt1=(250, 33), pt2=(329, 267)
# saved finding frame 11558 - pt1=(245, 38), pt2=(327, 263)
# saved finding frame 11559 - pt1=(251, 40), pt2=(328, 260)
# saved finding frame 11560 - pt1=(255, 30), pt2=(342, 266)
# saved finding frame 11561 - pt1=(268, 41), pt2=(337, 274)
# saved finding frame 11563 - pt1=(266, 44), pt2=(330, 293)
# saved finding frame 11564 - pt1=(253, 38), pt2=(335, 276)
# saved finding frame 11565 - pt1=(253, 45), pt2=(332, 274)
# saved finding frame 11566 - pt1=(254, 43), pt2=(331, 273)
# saved finding frame 11567 - pt1=(260, 57), pt2=(333, 260)
# saved finding frame 11568 - pt1=(258, 56), pt2=(332, 281)
