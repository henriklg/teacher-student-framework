# %%
import json
import os
import argparse

# %%
def get_dict(full_path):
    """
    gets a filename and return
    """
    
    with open(full_path, 'r') as f:
        tag_dict = json.load(f)
    
    return tag_dict

# %%
full_path = "/home/henriklg/master-thesis/data/hyper-capsule/metadata.json"

json = get_dict(full_path);

# %%
for vid_name, vid_data in json.items():
    # skip videos with no findings or segments (aka unlabeled videos)
    if vid_data["findings"] or vid_data["segments"]:
        print (vid_name)
        
        # go through findings and segments
        for finseg, finseg_data in vid_data.items():
            print (finseg)
            
            for 
            break
        break
# Out:
# 0728084c8da942d9
# ...
