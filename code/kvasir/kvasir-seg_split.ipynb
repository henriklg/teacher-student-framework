# %% [markdown]
# This notebook is for splitting kvasir-SEG into training and test data

# %%
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from pathlib import Path

import numpy as np
import cv2, os

# %% [markdown]
# Specify folder path and count number of samples

# %%
masked_path = Path('/mnt/sdb/Kvasir-SEG/masked_images/')
num_images = len([name for name in os.listdir(masked_path) if os.path.isfile(os.path.join(masked_path, name))])

# %%
masked_images = []
name_list = []

# iterate over all image paths
for path in masked_path.iterdir():
    if str(path).endswith(".jpg"):
        filename = path.name
        name_list.append(filename)
        masked_images.append(cv2.imread(str(path)))

# %%
X = masked_images
y = np.ones(1000)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
rand_int = np.random.randint(0, len(X_train))
rgb_im = cv2.cvtColor(X_train[rand_int], cv2.COLOR_BGR2RGB)

plt.imshow(rgb_im)
plt.title('Example image')
plt.axis('off')
plt.show()

print (len(y_train), y[0])
# Out:
# 670 1.0
