# %% [markdown]
# Kvasir dataset split into neg/pos and trained using Resnet50 without augmentation. Getting some decent results after training on resampled data with large step-size.
# - Class weighting
# - Resampling
# - Initial Bias-estimation
# - Decreasing learning rate

# %% [markdown]
# ### Loading images
# https://www.tensorflow.org/tutorials/load_data/images

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf

import numpy as np
import datetime
import time
import os
import pathlib
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import datetime

# Some stuff to make utils-function work
import sys
sys.path.append('../utils')
from pipeline import create_dataset, split_and_create_dataset, prepare_for_training
from create_model import create_model, create_callbacks
from utils import write_to_file, unpipe
# %load_ext autoreload
# %autoreload 2

# Jupyter-specific
# %matplotlib inline

project_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

# %% [markdown]
# Some parameters

# %%
data_dir = pathlib.Path('/home/henriklg/master-thesis/data/kvasir-v2/')

dir_name = "resnet50"
experiment = "imbalance"
log_dir = "./logs/{}_{}/{}".format(project_time, experiment, dir_name)

conf = {
    # Dataset
    "data_dir": data_dir,
    "ds_info": 'binary',
    "augment": ["crop","flip","brightness","saturation","contrast","rotate"],
    "aug_mult": 0,
    "resample": False,
    "class_weight": False,
    "shuffle_buffer_size": 2000,        # 0=no shuffling
    "seed": 2511,
    "neg_class": ['normal-cecum'],                 # select neg class for binary ds (normal class)
    "outcast": None,                   # list of folders to drop - currently only works for 1 item
    # Model
    "model": 'EfficientNetB0',
    "weights": None,                   # which weights to initialize the model with
    "dropout": 0.2,
    "num_epochs": 20,
    "batch_size": 16,
    "img_shape": (128, 128, 3),
    "learning_rate": 0.001,
    "optimizer": 'Adam',
    "final_activation": 'sigmoid',     # sigmoid for binary ds
    # Callbacks
    "tensorboard": False,
    "learning_schedule": False,
    "decay_rate": 0,                   # 128:0.25   64:1.0   32:4.0   16:16   8:64
    "checkpoint": False,
    "early_stopp": False,
    "early_stopp_patience": 7,
    # Misc
    "verbosity": 1,
    "keep_threshold": 0.0,
    "log_dir": log_dir,
    "cache_dir": "./cache"
    }

# %% [markdown]
# Create training, testing and validation dataset from utils/data_prep.py

# %%
train_ds, test_ds, val_ds = split_and_create_dataset(conf)
# Out:
# Negative                    :  1000 | 12.50%
# ---------------------------------------------
#      - normal-cecum         :  1000 | 12.50%
#
# Positive                    :  7000 | 87.50%
# ---------------------------------------------
#      - dyed-resection-margins :  1000 | 12.50%
#      - normal-z-line        :  1000 | 12.50%
#      - esophagitis          :  1000 | 12.50%
#      - normal-pylorus       :  1000 | 12.50%
#      - polyps               :  1000 | 12.50%
#      - ulcerative-colitis   :  1000 | 12.50%
#      - dyed-lifted-polyps   :  1000 | 12.50%
#
# Total number of image       : 8000
#
# Dataset.list_files:  /home/henriklg/master-thesis/data/kvasir-v2/*/*.*g
#
#
# Full dataset sample size:         8000
# Train dataset sample size:        5600
# Test dataset sample size:         1200
# Validation dataset sample size:   1200

# %% [markdown]
# # Training

# %% [markdown]
# ### Resnet50 transfer learning
# see https://adventuresinmachinelearning.com/transfer-learning-tensorflow-2/
# imbalanced-data: https://www.tensorflow.org/tutorials/structured_data/imbalanced_data

# %%
from tensorflow.python.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, LearningRateScheduler

# %%
metrics = [
        tf.keras.metrics.TruePositives(name='tp'),
        tf.keras.metrics.FalsePositives(name='fp'),
        tf.keras.metrics.TrueNegatives(name='tn'),
        tf.keras.metrics.FalseNegatives(name='fn'), 
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.AUC(name='auc'),
]

# %%
res_net = tf.keras.applications.ResNet50(
                weights='imagenet', 
                include_top=False, 
                input_shape=conf["img_shape"])

res_net.trainable = True

# %%
def make_model(output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)
    
    global_average_layer = GlobalAveragePooling2D()
    output_layer = Dense(1, activation=conf["final_activation"],
                         bias_initializer=output_bias)

    resnet50_model = tf.keras.Sequential([
            res_net,
            global_average_layer,
            output_layer])
    
    if conf['optimizer'] == 'Adam':
        opt = tf.keras.optimizers.Adam(learning_rate=conf["learning_rate"])
    elif conf['optimizer'] == 'SGD':
        opt = tf.keras.optimizers.SGD(learning_rate=conf["learning_rate"])

    resnet50_model.compile(
            optimizer=opt,
            loss=tf.keras.losses.BinaryCrossentropy(),
            metrics=metrics)
    
    return resnet50_model

# %% [markdown]
# ### Callbacks

# %%
callbacks = create_callbacks(conf)

# %% [markdown]
# ## Set correct initial bias

# %%
bias_model = make_model()

# Test run the model and show 10 first predictions of one epoch
bias_model.predict(train_ds.take(1))[:10]
# Out:
# array([[0.16293277],
#        [0.17168307],
#        [0.16304919],
#        [0.1664322 ],
#        [0.1710376 ],
#        [0.16840544],
#        [0.17127007],
#        [0.17077428],
#        [0.16916844],
#        [0.17339005]], dtype=float32)

# %%
results = bias_model.evaluate(train_ds, verbose=0, steps=conf["steps"]["train"])
print("Loss: {:0.4f}".format(results[0]))
# Out:
# Loss: 1.5693

# %%
initial_bias = np.log([conf["pos_count"]/conf["neg_count"]])
print ("The initial bias should then be: {:.4f}".format(initial_bias[0]))
# Out:
# The initial bias should then be: 1.9459

# %%
new_bias_model = make_model(output_bias = initial_bias)
new_bias_model.predict(train_ds, verbose=0, steps=conf["steps"]["train"])

print ("Initial guess should be around:", conf["pos_count"]/conf["sizes"]["total"])
new_bias_model.predict(train_ds.take(1))[:10]
# Out:
# Initial guess should be around: 0.875
# array([[0.90670645],
#        [0.90782046],
#        [0.90734464],
#        [0.90825945],
#        [0.90485156],
#        [0.9049826 ],
#        [0.9071683 ],
#        [0.9107182 ],
#        [0.90555364],
#        [0.90877044]], dtype=float32)

# %%
results = new_bias_model.evaluate(train_ds, verbose=0, steps=conf["steps"]["train"])
print("Loss: {:0.4f}".format(results[0]))
# Out:
# Loss: 0.3950

# %%
initial_weights = os.path.join(conf["log_dir"],'initial_weights')
new_bias_model.save_weights(initial_weights)

# %% [markdown]
# #### Confirm that the bias fix helps

# %%
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

def plot_loss(history, label, n):
    # Use a log scale to show the wide range of values.
    plt.semilogy(history.epoch,  history.history['loss'],
               color=colors[n], label='Train '+label)
    plt.semilogy(history.epoch,  history.history['val_loss'],
          color=colors[n], label='Val '+label,
          linestyle="--")
    plt.xlabel('Epoch')
    plt.ylabel('Loss')

    plt.legend()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

SMALL_SIZE = 12
MEDIUM_SIZE = 14
BIGGER_SIZE = 16

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %% [raw]
# model = make_model()
# model.load_weights(initial_weights)
# model.layers[-1].bias.assign([0.0])
# zero_bias_history = model.fit(
#     train_ds,
#     steps_per_epoch = conf["steps"]["train"],
#     epochs = 10,
#     validation_data = test_ds,
#     validation_steps = conf["steps"]["test"],
#     validation_freq = 1,
#     verbose=1)

# %% [raw]
# model = make_model()
# model.load_weights(initial_weights)
# careful_bias_history = model.fit(
#     train_ds,
#     steps_per_epoch = conf["steps"]["train"],
#     epochs = 10,
#     validation_data = test_ds,
#     validation_steps = conf["steps"]["test"],
#     validation_freq = 1,
#     verbose=1)

# %% [raw]
# plt.figure(figsize=(10,8))
# plot_loss(zero_bias_history, "Zero Bias", 0)
# plot_loss(careful_bias_history, "Careful Bias", 1)
# plt.savefig(conf["log_dir"]+"/bias_zero_vs_careful.pdf", format="pdf")

# %% [markdown]
# ## Some functions

# %%
def plot_metrics(history):
    metrics =  ['loss', 'auc', 'precision', 'recall']
    plt.figure(figsize=(12, 10))
    for n, metric in enumerate(metrics):
        name = metric.replace("_"," ").capitalize()
        plt.subplot(2,2,n+1)
        plt.plot(history.epoch, history.history[metric], color=colors[0], label='Train')
        plt.plot(history.epoch, history.history['val_'+metric],
                 color=colors[0], linestyle="--", label='Val')
        plt.xlabel('Epoch')
        plt.ylabel(name)
        if metric == 'loss':
            plt.ylim([0, plt.ylim()[1]])
        elif metric == 'auc':
            plt.ylim([0.8,1])
        else:
            plt.ylim([0,1])

        plt.legend()
    plt.tight_layout()

# %%
def plot_cm(labels, predictions, p=0.5):
    cm = confusion_matrix(labels, predictions > p)
    
    metrics_list = np.asarray([['tn', 'fp'], ['fn', 'tp']])
    labels = (np.asarray(["{0}\n{1:.0f}".format(metrics_list,cm) for metrics_list, cm in zip(metrics_list.flatten(), cm.flatten())])).reshape(2,2)
    
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=labels, fmt="", robust=True, annot_kws={'size':16})
    plt.title('Confusion matrix @{:.2f}'.format(p))
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')
    
    plt.ylim(2,0)

    print('Legitimate Lesions Detected (True Negatives): ', cm[0][0])
    print('Legitimate Lesions Incorrectly Detected (False Positives): ', cm[0][1])
    print('Fraudulent Lesions Missed (False Negatives): ', cm[1][0])
    print('Fraudulent Lesions Detected (True Positives): ', cm[1][1])
    print('Total Fraudulent Lesions: ', np.sum(cm[1]))
    print()

# %%
def plot_roc(name, labels, predictions, **kwargs):
    fp, tp, _ = roc_curve(labels, predictions)

    plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
    plt.xlabel('False positives [%]')
    plt.ylabel('True positives [%]')
    plt.xlim([-0.5,20])
    plt.ylim([80,100.5])
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')
    plt.tight_layout()

# %%
def numpify(dataset, model, samples=4000):
    ds_eval = dataset.unbatch().take(samples)
    labels = []
    images = []
    for img, lab in ds_eval:
        labels.append(lab.numpy())
        images.append(img.numpy())

    pred = model.predict(np.expand_dims(images, axis=0)[-1])
    
    return (labels, pred)

# %% [markdown]
# ## Baseline

# %%
baseline_model = make_model()
baseline_model.load_weights(initial_weights)

baseline_history = baseline_model.fit(
    train_ds,
    steps_per_epoch = conf["steps"]["train"],
    epochs = conf["num_epochs"],
    validation_data = test_ds,
    validation_steps = conf["steps"]["test"],
    validation_freq = 1,
    callbacks = callbacks
)
# Out:
# Epoch 1/20
# 350/350 [==============================] - 21s 61ms/step - loss: 0.1823 - tp: 9577.0000 - fp: 971.0000 - tn: 1225.0000 - fn: 5027.0000 - accuracy: 0.6430 - precision: 0.9079 - recall: 0.6558 - auc: 0.6652 - val_loss: 0.3603 - val_tp: 1060.0000 - val_fp: 140.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.8833 - val_precision: 0.8833 - val_recall: 1.0000 - val_auc: 0.5051
# Epoch 2/20
# 350/350 [==============================] - 20s 57ms/step - loss: 0.1184 - tp: 4758.0000 - fp: 150.0000 - tn: 582.0000 - fn: 110.0000 - accuracy: 0.9536 - precision: 0.9694 - recall: 0.9774 - auc: 0.9790 - val_loss: 0.3704 - val_tp: 1060.0000 - val_fp: 140.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.8833 - val_precision: 0.8833 - val_recall: 1.0000 - val_auc: 0.5826
# Epoch 3/20
# 350/350 [==============================] - 20s 56ms/step - loss: 0.1090 - tp: 4750.0000 - fp: 119.0000 - tn: 613.0000 - fn: 118.0000 - accuracy: 0.9577 - precision: 0.9756 - recall: 0.9758 - auc: 0.9825 - val_loss: 0.1497 - val_tp: 983.0000 - val_fp: 2.0000 - val_tn: 138.0000 - val_fn: 77.0000 - val_accuracy: 0.9342 - val_precision: 0.9980 - val_recall: 0.9274 - val_auc: 0.9930
# Epoch 4/20
# 350/350 [==============================] - 20s 57ms/step - loss: 0.0857 - tp: 4774.0000 - fp: 87.0000 - tn: 645.0000 - fn: 94.0000 - accuracy: 0.9677 - precision: 0.9821 - recall: 0.9807 - auc: 0.9897 - val_loss: 0.2055 - val_tp: 1060.0000 - val_fp: 120.0000 - val_tn: 20.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9000 - val_precision: 0.8983 - val_recall: 1.0000 - val_auc: 0.9882
# Epoch 5/20
# 350/350 [==============================] - 20s 57ms/step - loss: 0.0909 - tp: 4774.0000 - fp: 98.0000 - tn: 634.0000 - fn: 94.0000 - accuracy: 0.9657 - precision: 0.9799 - recall: 0.9807 - auc: 0.9871 - val_loss: 0.0820 - val_tp: 1038.0000 - val_fp: 12.0000 - val_tn: 128.0000 - val_fn: 22.0000 - val_accuracy: 0.9717 - val_precision: 0.9886 - val_recall: 0.9792 - val_auc: 0.9917
# Epoch 6/20
# 350/350 [==============================] - 20s 57ms/step - loss: 0.0847 - tp: 4772.0000 - fp: 91.0000 - tn: 641.0000 - fn: 96.0000 - accuracy: 0.9666 - precision: 0.9813 - recall: 0.9803 - auc: 0.9887 - val_loss: 0.1146 - val_tp: 1057.0000 - val_fp: 68.0000 - val_tn: 72.0000 - val_fn: 3.0000 - val_accuracy: 0.9408 - val_precision: 0.9396 - val_recall: 0.9972 - val_auc: 0.9953
# Epoch 7/20
# 350/350 [==============================] - 20s 57ms/step - loss: 0.0733 - tp: 4797.0000 - fp: 79.0000 - tn: 653.0000 - fn: 71.0000 - accuracy: 0.9732 - precision: 0.9838 - recall: 0.9854 - auc: 0.9908 - val_loss: 0.0814 - val_tp: 1022.0000 - val_fp: 0.0000e+00 - val_tn: 140.0000 - val_fn: 38.0000 - val_accuracy: 0.9683 - val_precision: 1.0000 - val_recall: 0.9642 - val_auc: 0.9973
# Epoch 8/20
# 350/350 [==============================] - 20s 57ms/step - loss: 0.0731 - tp: 4794.0000 - fp: 87.0000 - tn: 645.0000 - fn: 74.0000 - accuracy: 0.9712 - precision: 0.9822 - recall: 0.9848 - auc: 0.9910 - val_loss: 0.0592 - val_tp: 1046.0000 - val_fp: 9.0000 - val_tn: 131.0000 - val_fn: 14.0000 - val_accuracy: 0.9808 - val_precision: 0.9915 - val_recall: 0.9868 - val_auc: 0.9950
# Epoch 9/20
# 350/350 [==============================] - 20s 57ms/step - loss: 0.0639 - tp: 4803.0000 - fp: 59.0000 - tn: 673.0000 - fn: 65.0000 - accuracy: 0.9779 - precision: 0.9879 - recall: 0.9866 - auc: 0.9931 - val_loss: 0.0540 - val_tp: 1039.0000 - val_fp: 0.0000e+00 - val_tn: 140.0000 - val_fn: 21.0000 - val_accuracy: 0.9825 - val_precision: 1.0000 - val_recall: 0.9802 - val_auc: 0.9983
# Epoch 10/20
# 350/350 [==============================] - 20s 57ms/step - loss: 0.0591 - tp: 4799.0000 - fp: 55.0000 - tn: 677.0000 - fn: 69.0000 - accuracy: 0.9779 - precision: 0.9887 - recall: 0.9858 - auc: 0.9937 - val_loss: 0.2318 - val_tp: 958.0000 - val_fp: 1.0000 - val_tn: 139.0000 - val_fn: 102.0000 - val_accuracy: 0.9142 - val_precision: 0.9990 - val_recall: 0.9038 - val_auc: 0.9936
# Epoch 11/20
# 350/350 [==============================] - 20s 58ms/step - loss: 0.0687 - tp: 4804.0000 - fp: 64.0000 - tn: 668.0000 - fn: 64.0000 - accuracy: 0.9771 - precision: 0.9869 - recall: 0.9869 - auc: 0.9929 - val_loss: 0.1696 - val_tp: 1015.0000 - val_fp: 1.0000 - val_tn: 139.0000 - val_fn: 45.0000 - val_accuracy: 0.9617 - val_precision: 0.9990 - val_recall: 0.9575 - val_auc: 0.9937
# Epoch 12/20
# 350/350 [==============================] - 20s 57ms/step - loss: 0.0578 - tp: 4807.0000 - fp: 49.0000 - tn: 683.0000 - fn: 61.0000 - accuracy: 0.9804 - precision: 0.9899 - recall: 0.9875 - auc: 0.9952 - val_loss: 0.0381 - val_tp: 1051.0000 - val_fp: 7.0000 - val_tn: 133.0000 - val_fn: 9.0000 - val_accuracy: 0.9867 - val_precision: 0.9934 - val_recall: 0.9915 - val_auc: 0.9978
# Epoch 13/20
# 350/350 [==============================] - 20s 57ms/step - loss: 0.0589 - tp: 4808.0000 - fp: 57.0000 - tn: 675.0000 - fn: 60.0000 - accuracy: 0.9791 - precision: 0.9883 - recall: 0.9877 - auc: 0.9935 - val_loss: 0.1067 - val_tp: 1011.0000 - val_fp: 0.0000e+00 - val_tn: 140.0000 - val_fn: 49.0000 - val_accuracy: 0.9592 - val_precision: 1.0000 - val_recall: 0.9538 - val_auc: 0.9973
# Epoch 14/20
# 350/350 [==============================] - 20s 58ms/step - loss: 0.0531 - tp: 4811.0000 - fp: 52.0000 - tn: 680.0000 - fn: 57.0000 - accuracy: 0.9805 - precision: 0.9893 - recall: 0.9883 - auc: 0.9953 - val_loss: 0.1167 - val_tp: 1060.0000 - val_fp: 68.0000 - val_tn: 72.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9433 - val_precision: 0.9397 - val_recall: 1.0000 - val_auc: 0.9916
# Epoch 15/20
# 350/350 [==============================] - 20s 58ms/step - loss: 0.0486 - tp: 4812.0000 - fp: 44.0000 - tn: 688.0000 - fn: 56.0000 - accuracy: 0.9821 - precision: 0.9909 - recall: 0.9885 - auc: 0.9955 - val_loss: 0.1641 - val_tp: 990.0000 - val_fp: 0.0000e+00 - val_tn: 140.0000 - val_fn: 70.0000 - val_accuracy: 0.9417 - val_precision: 1.0000 - val_recall: 0.9340 - val_auc: 0.9972
# Epoch 16/20
# 350/350 [==============================] - 20s 58ms/step - loss: 0.0418 - tp: 4821.0000 - fp: 40.0000 - tn: 692.0000 - fn: 47.0000 - accuracy: 0.9845 - precision: 0.9918 - recall: 0.9903 - auc: 0.9970 - val_loss: 0.0509 - val_tp: 1039.0000 - val_fp: 3.0000 - val_tn: 137.0000 - val_fn: 21.0000 - val_accuracy: 0.9800 - val_precision: 0.9971 - val_recall: 0.9802 - val_auc: 0.9977
# Epoch 17/20
# 350/350 [==============================] - 20s 57ms/step - loss: 0.0582 - tp: 4811.0000 - fp: 61.0000 - tn: 671.0000 - fn: 57.0000 - accuracy: 0.9789 - precision: 0.9875 - recall: 0.9883 - auc: 0.9932 - val_loss: 0.0679 - val_tp: 1030.0000 - val_fp: 4.0000 - val_tn: 136.0000 - val_fn: 30.0000 - val_accuracy: 0.9717 - val_precision: 0.9961 - val_recall: 0.9717 - val_auc: 0.9958
# Epoch 18/20
# 350/350 [==============================] - 20s 58ms/step - loss: 0.0690 - tp: 4793.0000 - fp: 70.0000 - tn: 662.0000 - fn: 75.0000 - accuracy: 0.9741 - precision: 0.9856 - recall: 0.9846 - auc: 0.9934 - val_loss: 0.0370 - val_tp: 1045.0000 - val_fp: 5.0000 - val_tn: 135.0000 - val_fn: 15.0000 - val_accuracy: 0.9833 - val_precision: 0.9952 - val_recall: 0.9858 - val_auc: 0.9985
# Epoch 19/20
# 350/350 [==============================] - 20s 58ms/step - loss: 0.0528 - tp: 4813.0000 - fp: 52.0000 - tn: 680.0000 - fn: 55.0000 - accuracy: 0.9809 - precision: 0.9893 - recall: 0.9887 - auc: 0.9954 - val_loss: 0.0310 - val_tp: 1048.0000 - val_fp: 2.0000 - val_tn: 138.0000 - val_fn: 12.0000 - val_accuracy: 0.9883 - val_precision: 0.9981 - val_recall: 0.9887 - val_auc: 0.9991
# Epoch 20/20
# 350/350 [==============================] - 21s 61ms/step - loss: 0.0494 - tp: 4814.0000 - fp: 55.0000 - tn: 677.0000 - fn: 54.0000 - accuracy: 0.9805 - precision: 0.9887 - recall: 0.9889 - auc: 0.9961 - val_loss: 0.1416 - val_tp: 995.0000 - val_fp: 1.0000 - val_tn: 139.0000 - val_fn: 65.0000 - val_accuracy: 0.9450 - val_precision: 0.9990 - val_recall: 0.9387 - val_auc: 0.9959

# %% [markdown]
# #### Validate the results

# %%
from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns

# %%
plot_metrics(baseline_history)
plt.savefig(conf["log_dir"]+"/baseline_metrics_plot")

# %%
baseline_results = baseline_model.evaluate(val_ds, verbose=2, steps=conf["steps"]["val"])
print()

f = open(conf["log_dir"]+"/baseline_val_results.txt","w")
for name, value in zip(baseline_model.metrics_names, baseline_results):
    line = "{} : {}\n".format(name, value)
    print(line, end='')
    f.write(line)
f.close()
print()
# Out:
# 75/75 - 1s - loss: 0.1543 - tp: 987.0000 - fp: 1.0000 - tn: 140.0000 - fn: 72.0000 - accuracy: 0.9392 - precision: 0.9990 - recall: 0.9320 - auc: 0.9952
#
# loss : 0.15430134534835815
# tp : 987.0
# fp : 1.0
# tn : 140.0
# fn : 72.0
# accuracy : 0.9391666650772095
# precision : 0.9989878535270691
# recall : 0.9320113062858582
# auc : 0.9951814413070679

# %%
train_labels_baseline, train_predictions_baseline = numpify(train_ds, baseline_model, samples=5000)
val_labels_baseline, val_predictions_baseline = numpify(val_ds, baseline_model, samples=5000)

# %%
plot_cm(train_labels_baseline, train_predictions_baseline)
plt.savefig(conf["log_dir"]+"/baseline_cm_plot")
# Out:
# Legitimate Lesions Detected (True Negatives):  619
# Legitimate Lesions Incorrectly Detected (False Positives):  19
# Fraudulent Lesions Missed (False Negatives):  227
# Fraudulent Lesions Detected (True Positives):  4135
# Total Fraudulent Lesions:  4362

# %%
plt.figure(figsize=(10,10))

plot_roc("Train Baseline", train_labels_baseline, train_predictions_baseline, color=colors[0])
plot_roc("Test Baseline", val_labels_baseline, val_predictions_baseline, color=colors[0], linestyle='--')

plt.legend(loc='lower right');
plt.savefig(conf["log_dir"]+"/baseline_roc_plot.pdf", format="pdf")

# %% [markdown]
# ### Calculate class weights
# See https://www.tensorflow.org/tutorials/structured_data/imbalanced_data#class_weights

# %%
weight_for_0 = (1/conf["neg_count"])*(conf["sizes"]["total"])/2.0
weight_for_1 = (1/conf["pos_count"])*(conf["sizes"]["total"])/2.0

class_weight = {0: weight_for_0,
                1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 4.00
# Weight for class 1: 0.57

# %%
weighted_model = make_model()
weighted_model.load_weights(initial_weights)

weighted_history = weighted_model.fit(
    train_ds,
    steps_per_epoch = conf["steps"]["train"],
    epochs = conf["num_epochs"],
    validation_data = test_ds,
    validation_steps = conf["steps"]["test"],
    validation_freq = 1,
    class_weight = class_weight,
    callbacks = callbacks
)
# Out:
# Epoch 1/20
# 350/350 [==============================] - 21s 60ms/step - loss: 0.2555 - tp: 5348.0000 - fp: 57.0000 - tn: 816.0000 - fn: 579.0000 - accuracy: 0.9065 - precision: 0.9895 - recall: 0.9023 - auc: 0.9699 - val_loss: 0.3603 - val_tp: 1060.0000 - val_fp: 140.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.8833 - val_precision: 0.8833 - val_recall: 1.0000 - val_auc: 0.7489
# Epoch 2/20
# 350/350 [==============================] - 22s 62ms/step - loss: 0.1931 - tp: 4458.0000 - fp: 40.0000 - tn: 692.0000 - fn: 410.0000 - accuracy: 0.9196 - precision: 0.9911 - recall: 0.9158 - auc: 0.9765 - val_loss: 0.3714 - val_tp: 932.0000 - val_fp: 53.0000 - val_tn: 87.0000 - val_fn: 128.0000 - val_accuracy: 0.8492 - val_precision: 0.9462 - val_recall: 0.8792 - val_auc: 0.8802
# Epoch 3/20
# 350/350 [==============================] - 20s 57ms/step - loss: 0.2055 - tp: 4501.0000 - fp: 33.0000 - tn: 699.0000 - fn: 367.0000 - accuracy: 0.9286 - precision: 0.9927 - recall: 0.9246 - auc: 0.9807 - val_loss: 0.5577 - val_tp: 973.0000 - val_fp: 53.0000 - val_tn: 87.0000 - val_fn: 87.0000 - val_accuracy: 0.8833 - val_precision: 0.9483 - val_recall: 0.9179 - val_auc: 0.8364
# Epoch 4/20
# 350/350 [==============================] - 20s 57ms/step - loss: 0.1807 - tp: 4485.0000 - fp: 43.0000 - tn: 689.0000 - fn: 383.0000 - accuracy: 0.9239 - precision: 0.9905 - recall: 0.9213 - auc: 0.9794 - val_loss: 179.3382 - val_tp: 1060.0000 - val_fp: 140.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.8833 - val_precision: 0.8833 - val_recall: 1.0000 - val_auc: 0.5000
# Epoch 5/20
# 350/350 [==============================] - 20s 58ms/step - loss: 0.3257 - tp: 4317.0000 - fp: 59.0000 - tn: 673.0000 - fn: 551.0000 - accuracy: 0.8911 - precision: 0.9865 - recall: 0.8868 - auc: 0.9448 - val_loss: 0.9251 - val_tp: 776.0000 - val_fp: 2.0000 - val_tn: 138.0000 - val_fn: 284.0000 - val_accuracy: 0.7617 - val_precision: 0.9974 - val_recall: 0.7321 - val_auc: 0.9053
# Epoch 6/20
# 350/350 [==============================] - 21s 59ms/step - loss: 0.1972 - tp: 4451.0000 - fp: 28.0000 - tn: 704.0000 - fn: 417.0000 - accuracy: 0.9205 - precision: 0.9937 - recall: 0.9143 - auc: 0.9729 - val_loss: 0.3144 - val_tp: 945.0000 - val_fp: 1.0000 - val_tn: 139.0000 - val_fn: 115.0000 - val_accuracy: 0.9033 - val_precision: 0.9989 - val_recall: 0.8915 - val_auc: 0.9903
# Epoch 7/20
# 350/350 [==============================] - 20s 56ms/step - loss: 0.1638 - tp: 4537.0000 - fp: 29.0000 - tn: 703.0000 - fn: 331.0000 - accuracy: 0.9357 - precision: 0.9936 - recall: 0.9320 - auc: 0.9815 - val_loss: 0.1571 - val_tp: 990.0000 - val_fp: 1.0000 - val_tn: 139.0000 - val_fn: 70.0000 - val_accuracy: 0.9408 - val_precision: 0.9990 - val_recall: 0.9340 - val_auc: 0.9939
# Epoch 8/20
# 350/350 [==============================] - 20s 56ms/step - loss: 0.1404 - tp: 4582.0000 - fp: 29.0000 - tn: 703.0000 - fn: 286.0000 - accuracy: 0.9438 - precision: 0.9937 - recall: 0.9412 - auc: 0.9865 - val_loss: 0.0943 - val_tp: 1027.0000 - val_fp: 1.0000 - val_tn: 139.0000 - val_fn: 33.0000 - val_accuracy: 0.9717 - val_precision: 0.9990 - val_recall: 0.9689 - val_auc: 0.9954
# Epoch 9/20
# 350/350 [==============================] - 21s 59ms/step - loss: 0.1523 - tp: 4557.0000 - fp: 28.0000 - tn: 704.0000 - fn: 311.0000 - accuracy: 0.9395 - precision: 0.9939 - recall: 0.9361 - auc: 0.9838 - val_loss: 0.1127 - val_tp: 1046.0000 - val_fp: 52.0000 - val_tn: 88.0000 - val_fn: 14.0000 - val_accuracy: 0.9450 - val_precision: 0.9526 - val_recall: 0.9868 - val_auc: 0.9857
# Epoch 10/20
# 350/350 [==============================] - 22s 62ms/step - loss: 0.1271 - tp: 4600.0000 - fp: 27.0000 - tn: 705.0000 - fn: 268.0000 - accuracy: 0.9473 - precision: 0.9942 - recall: 0.9449 - auc: 0.9888 - val_loss: 0.0754 - val_tp: 1052.0000 - val_fp: 30.0000 - val_tn: 110.0000 - val_fn: 8.0000 - val_accuracy: 0.9683 - val_precision: 0.9723 - val_recall: 0.9925 - val_auc: 0.9944
# Epoch 11/20
# 350/350 [==============================] - 21s 59ms/step - loss: 0.1164 - tp: 4650.0000 - fp: 26.0000 - tn: 706.0000 - fn: 218.0000 - accuracy: 0.9564 - precision: 0.9944 - recall: 0.9552 - auc: 0.9894 - val_loss: 0.2136 - val_tp: 967.0000 - val_fp: 1.0000 - val_tn: 139.0000 - val_fn: 93.0000 - val_accuracy: 0.9217 - val_precision: 0.9990 - val_recall: 0.9123 - val_auc: 0.9906
# Epoch 12/20
# 350/350 [==============================] - 20s 57ms/step - loss: 0.1058 - tp: 4668.0000 - fp: 16.0000 - tn: 716.0000 - fn: 200.0000 - accuracy: 0.9614 - precision: 0.9966 - recall: 0.9589 - auc: 0.9912 - val_loss: 0.1129 - val_tp: 1019.0000 - val_fp: 1.0000 - val_tn: 139.0000 - val_fn: 41.0000 - val_accuracy: 0.9650 - val_precision: 0.9990 - val_recall: 0.9613 - val_auc: 0.9941
# Epoch 13/20
# 350/350 [==============================] - 20s 56ms/step - loss: 0.1434 - tp: 4576.0000 - fp: 30.0000 - tn: 702.0000 - fn: 292.0000 - accuracy: 0.9425 - precision: 0.9935 - recall: 0.9400 - auc: 0.9856 - val_loss: 0.3455 - val_tp: 916.0000 - val_fp: 0.0000e+00 - val_tn: 140.0000 - val_fn: 144.0000 - val_accuracy: 0.8800 - val_precision: 1.0000 - val_recall: 0.8642 - val_auc: 0.9911
# Epoch 14/20
# 350/350 [==============================] - 20s 56ms/step - loss: 0.1180 - tp: 4643.0000 - fp: 20.0000 - tn: 712.0000 - fn: 225.0000 - accuracy: 0.9563 - precision: 0.9957 - recall: 0.9538 - auc: 0.9894 - val_loss: 0.5820 - val_tp: 846.0000 - val_fp: 0.0000e+00 - val_tn: 140.0000 - val_fn: 214.0000 - val_accuracy: 0.8217 - val_precision: 1.0000 - val_recall: 0.7981 - val_auc: 0.9821
# Epoch 15/20
# 350/350 [==============================] - 20s 57ms/step - loss: 0.1072 - tp: 4663.0000 - fp: 21.0000 - tn: 711.0000 - fn: 205.0000 - accuracy: 0.9596 - precision: 0.9955 - recall: 0.9579 - auc: 0.9913 - val_loss: 0.1126 - val_tp: 1014.0000 - val_fp: 1.0000 - val_tn: 139.0000 - val_fn: 46.0000 - val_accuracy: 0.9608 - val_precision: 0.9990 - val_recall: 0.9566 - val_auc: 0.9959
# Epoch 16/20
# 350/350 [==============================] - 21s 60ms/step - loss: 0.0999 - tp: 4653.0000 - fp: 15.0000 - tn: 717.0000 - fn: 215.0000 - accuracy: 0.9589 - precision: 0.9968 - recall: 0.9558 - auc: 0.9923 - val_loss: 0.0887 - val_tp: 1054.0000 - val_fp: 31.0000 - val_tn: 109.0000 - val_fn: 6.0000 - val_accuracy: 0.9692 - val_precision: 0.9714 - val_recall: 0.9943 - val_auc: 0.9908
# Epoch 17/20
# 350/350 [==============================] - 21s 60ms/step - loss: 0.1103 - tp: 4636.0000 - fp: 23.0000 - tn: 709.0000 - fn: 232.0000 - accuracy: 0.9545 - precision: 0.9951 - recall: 0.9523 - auc: 0.9911 - val_loss: 0.0823 - val_tp: 1033.0000 - val_fp: 5.0000 - val_tn: 135.0000 - val_fn: 27.0000 - val_accuracy: 0.9733 - val_precision: 0.9952 - val_recall: 0.9745 - val_auc: 0.9923
# Epoch 18/20
# 350/350 [==============================] - 21s 59ms/step - loss: 0.1401 - tp: 4600.0000 - fp: 29.0000 - tn: 703.0000 - fn: 268.0000 - accuracy: 0.9470 - precision: 0.9937 - recall: 0.9449 - auc: 0.9875 - val_loss: 0.1193 - val_tp: 1023.0000 - val_fp: 1.0000 - val_tn: 139.0000 - val_fn: 37.0000 - val_accuracy: 0.9683 - val_precision: 0.9990 - val_recall: 0.9651 - val_auc: 0.9945
# Epoch 19/20
# 350/350 [==============================] - 21s 60ms/step - loss: 0.0999 - tp: 4674.0000 - fp: 20.0000 - tn: 712.0000 - fn: 194.0000 - accuracy: 0.9618 - precision: 0.9957 - recall: 0.9601 - auc: 0.9925 - val_loss: 0.0586 - val_tp: 1037.0000 - val_fp: 2.0000 - val_tn: 138.0000 - val_fn: 23.0000 - val_accuracy: 0.9792 - val_precision: 0.9981 - val_recall: 0.9783 - val_auc: 0.9970
# Epoch 20/20
# 350/350 [==============================] - 21s 60ms/step - loss: 0.0926 - tp: 4690.0000 - fp: 20.0000 - tn: 712.0000 - fn: 178.0000 - accuracy: 0.9646 - precision: 0.9958 - recall: 0.9634 - auc: 0.9931 - val_loss: 0.0686 - val_tp: 1035.0000 - val_fp: 1.0000 - val_tn: 139.0000 - val_fn: 25.0000 - val_accuracy: 0.9783 - val_precision: 0.9990 - val_recall: 0.9764 - val_auc: 0.9965

# %%
plot_metrics(weighted_history)
plt.savefig(conf["log_dir"]+"/weighted_metrics_plot.pdf", format="pdf")

# %%
weighted_results = weighted_model.evaluate(val_ds, verbose=2, steps=conf["steps"]["val"])
print()

f = open(conf["log_dir"]+"/weighted_val_results.txt","w")
for name, value in zip(baseline_model.metrics_names, weighted_results):
    line = "{} : {}\n".format(name, value)
    print(line, end='')
    f.write(line)
f.close()
print()
# Out:
# 75/75 - 1s - loss: 0.0737 - tp: 1032.0000 - fp: 1.0000 - tn: 140.0000 - fn: 27.0000 - accuracy: 0.9767 - precision: 0.9990 - recall: 0.9745 - auc: 0.9965
#
# loss : 0.07371287792921066
# tp : 1032.0
# fp : 1.0
# tn : 140.0
# fn : 27.0
# accuracy : 0.9766666889190674
# precision : 0.9990319609642029
# recall : 0.9745042324066162
# auc : 0.9965007305145264

# %%
train_labels_weighted, train_predictions_weighted = numpify(train_ds, weighted_model, samples=5000)
val_labels_weighted, val_predictions_weighted = numpify(val_ds, weighted_model, samples=5000)

# %%
plot_cm(train_labels_weighted, train_predictions_weighted)
plt.savefig(conf["log_dir"]+"/weighted_cm_plot.pdf", format="pdf")
# Out:
# Legitimate Lesions Detected (True Negatives):  644
# Legitimate Lesions Incorrectly Detected (False Positives):  6
# Fraudulent Lesions Missed (False Negatives):  102
# Fraudulent Lesions Detected (True Positives):  4248
# Total Fraudulent Lesions:  4350

# %%
plt.figure(figsize=(10,10))

plot_roc("Train Baseline", train_labels_baseline, train_predictions_baseline, color=colors[0])
plot_roc("Val Baseline", val_labels_baseline, val_predictions_baseline, color=colors[0], linestyle='--')

plot_roc("Train Weighted", train_labels_weighted, train_predictions_weighted, color=colors[1])
plot_roc("Val Weighted", val_labels_weighted, val_predictions_weighted, color=colors[1], linestyle='--')

plt.legend(loc='lower right');
plt.savefig(conf["log_dir"]+"/weighted_roc_plot.pdf", format="pdf")

# %% [markdown]
# ## Oversampling the minority class

# %%
# Remove the cache
# !rm -rf ./cache/*

# %%
# Set dataset resample to true to make 5050 distribution of samples
conf["resample"] = True

# %% [markdown]
# Create training, testing and validation dataset from utils/data_prep.py

# %%
conf["num_classes"] = 2

# %%
train_ds_resampled, test_ds_resampled, val_ds_resampled = split_and_create_dataset(conf)
# Out:
# Negative                    :  1000 | 12.50%
# ---------------------------------------------
#      - normal-cecum         :  1000 | 12.50%
#
# Positive                    :  7000 | 87.50%
# ---------------------------------------------
#      - dyed-resection-margins :  1000 | 12.50%
#      - normal-z-line        :  1000 | 12.50%
#      - esophagitis          :  1000 | 12.50%
#      - normal-pylorus       :  1000 | 12.50%
#      - polyps               :  1000 | 12.50%
#      - ulcerative-colitis   :  1000 | 12.50%
#      - dyed-lifted-polyps   :  1000 | 12.50%
#
# Total number of image       : 8000
#
# Dataset.list_files:  /home/henriklg/master-thesis/data/kvasir-v2/*/*.*g
#
#
# Full dataset sample size:         8000
# Train dataset sample size:        5600
# Test dataset sample size:         1200
# Validation dataset sample size:   1200
#
# ---- Ratios before resampling ----
# [0.12553571 0.87446429]
#
# ---- Ratios after resampling ----
# [0.49326172 0.5067383 ]

# %%
# Check the mean value is close to 0.5
for img, label in train_ds_resampled.take(3):
    print(label.numpy().mean())
# Out:
# 0.5625
# 0.5
# 0.5

# %%
resampled_model = make_model()
resampled_model.load_weights(initial_weights)

resampled_history = resampled_model.fit(
    train_ds_resampled,
    steps_per_epoch = conf["steps"]["train"],
    epochs = conf["num_epochs"],
    validation_data = test_ds_resampled,
    validation_steps = conf["steps"]["test"],
    validation_freq = 1,
    callbacks = callbacks
)
# Out:
# Epoch 1/20
# 350/350 [==============================] - 32s 91ms/step - loss: 0.2401 - tp: 3672.0000 - fp: 230.0000 - tn: 2641.0000 - fn: 257.0000 - accuracy: 0.9284 - precision: 0.9411 - recall: 0.9346 - auc: 0.9748 - val_loss: 0.3613 - val_tp: 1060.0000 - val_fp: 140.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.8833 - val_precision: 0.8833 - val_recall: 1.0000 - val_auc: 0.3872
# Epoch 2/20
# 350/350 [==============================] - 19s 53ms/step - loss: 0.1443 - tp: 2617.0000 - fp: 112.0000 - tn: 2704.0000 - fn: 167.0000 - accuracy: 0.9502 - precision: 0.9590 - recall: 0.9400 - auc: 0.9856 - val_loss: 0.3413 - val_tp: 1060.0000 - val_fp: 140.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.8833 - val_precision: 0.8833 - val_recall: 1.0000 - val_auc: 0.72920 - fp: 106.0000 - tn: 2457.0000 - fn: 151.0000 - accuracy: 0.9492 - precision: 0.9567 - r
# Epoch 3/20
# 350/350 [==============================] - 19s 55ms/step - loss: 0.1044 - tp: 2711.0000 - fp: 83.0000 - tn: 2692.0000 - fn: 114.0000 - accuracy: 0.9648 - precision: 0.9703 - recall: 0.9596 - auc: 0.9916 - val_loss: 0.1542 - val_tp: 999.0000 - val_fp: 0.0000e+00 - val_tn: 140.0000 - val_fn: 61.0000 - val_accuracy: 0.9492 - val_precision: 1.0000 - val_recall: 0.9425 - val_auc: 0.9956
# Epoch 4/20
# 350/350 [==============================] - 19s 56ms/step - loss: 0.0764 - tp: 2734.0000 - fp: 61.0000 - tn: 2723.0000 - fn: 82.0000 - accuracy: 0.9745 - precision: 0.9782 - recall: 0.9709 - auc: 0.9948 - val_loss: 0.0894 - val_tp: 1029.0000 - val_fp: 1.0000 - val_tn: 139.0000 - val_fn: 31.0000 - val_accuracy: 0.9733 - val_precision: 0.9990 - val_recall: 0.9708 - val_auc: 0.9979
# Epoch 5/20
# 350/350 [==============================] - 20s 57ms/step - loss: 0.0887 - tp: 2653.0000 - fp: 60.0000 - tn: 2784.0000 - fn: 103.0000 - accuracy: 0.9709 - precision: 0.9779 - recall: 0.9626 - auc: 0.9931 - val_loss: 0.0794 - val_tp: 1030.0000 - val_fp: 9.0000 - val_tn: 131.0000 - val_fn: 30.0000 - val_accuracy: 0.9675 - val_precision: 0.9913 - val_recall: 0.9717 - val_auc: 0.9948
# Epoch 6/20
# 350/350 [==============================] - 20s 57ms/step - loss: 0.0867 - tp: 2638.0000 - fp: 66.0000 - tn: 2805.0000 - fn: 91.0000 - accuracy: 0.9720 - precision: 0.9756 - recall: 0.9667 - auc: 0.9934 - val_loss: 0.0381 - val_tp: 1051.0000 - val_fp: 5.0000 - val_tn: 135.0000 - val_fn: 9.0000 - val_accuracy: 0.9883 - val_precision: 0.9953 - val_recall: 0.9915 - val_auc: 0.9980
# Epoch 7/20
# 350/350 [==============================] - 20s 58ms/step - loss: 0.0672 - tp: 2714.0000 - fp: 40.0000 - tn: 2773.0000 - fn: 73.0000 - accuracy: 0.9798 - precision: 0.9855 - recall: 0.9738 - auc: 0.9957 - val_loss: 0.0656 - val_tp: 1040.0000 - val_fp: 5.0000 - val_tn: 135.0000 - val_fn: 20.0000 - val_accuracy: 0.9792 - val_precision: 0.9952 - val_recall: 0.9811 - val_auc: 0.9943
# Epoch 8/20
# 350/350 [==============================] - 19s 54ms/step - loss: 0.0528 - tp: 2766.0000 - fp: 35.0000 - tn: 2741.0000 - fn: 58.0000 - accuracy: 0.9834 - precision: 0.9875 - recall: 0.9795 - auc: 0.9973 - val_loss: 0.0858 - val_tp: 1027.0000 - val_fp: 2.0000 - val_tn: 138.0000 - val_fn: 33.0000 - val_accuracy: 0.9708 - val_precision: 0.9981 - val_recall: 0.9689 - val_auc: 0.9957
# Epoch 9/20
# 350/350 [==============================] - 19s 54ms/step - loss: 0.0686 - tp: 2673.0000 - fp: 46.0000 - tn: 2800.0000 - fn: 81.0000 - accuracy: 0.9773 - precision: 0.9831 - recall: 0.9706 - auc: 0.9961 - val_loss: 0.1189 - val_tp: 1015.0000 - val_fp: 4.0000 - val_tn: 136.0000 - val_fn: 45.0000 - val_accuracy: 0.9592 - val_precision: 0.9961 - val_recall: 0.9575 - val_auc: 0.9919
# Epoch 10/20
# 350/350 [==============================] - 19s 54ms/step - loss: 0.0505 - tp: 2697.0000 - fp: 33.0000 - tn: 2809.0000 - fn: 61.0000 - accuracy: 0.9832 - precision: 0.9879 - recall: 0.9779 - auc: 0.9974 - val_loss: 0.0962 - val_tp: 1060.0000 - val_fp: 45.0000 - val_tn: 95.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9625 - val_precision: 0.9593 - val_recall: 1.0000 - val_auc: 0.9914
# Epoch 11/20
# 350/350 [==============================] - 19s 54ms/step - loss: 0.0523 - tp: 2783.0000 - fp: 29.0000 - tn: 2730.0000 - fn: 58.0000 - accuracy: 0.9845 - precision: 0.9897 - recall: 0.9796 - auc: 0.9969 - val_loss: 0.1778 - val_tp: 998.0000 - val_fp: 2.0000 - val_tn: 138.0000 - val_fn: 62.0000 - val_accuracy: 0.9467 - val_precision: 0.9980 - val_recall: 0.9415 - val_auc: 0.9937
# Epoch 12/20
# 350/350 [==============================] - 19s 54ms/step - loss: 0.0590 - tp: 2740.0000 - fp: 41.0000 - tn: 2756.0000 - fn: 63.0000 - accuracy: 0.9814 - precision: 0.9853 - recall: 0.9775 - auc: 0.9963 - val_loss: 0.1104 - val_tp: 1035.0000 - val_fp: 24.0000 - val_tn: 116.0000 - val_fn: 25.0000 - val_accuracy: 0.9592 - val_precision: 0.9773 - val_recall: 0.9764 - val_auc: 0.9795
# Epoch 13/20
# 350/350 [==============================] - 19s 54ms/step - loss: 0.0448 - tp: 2778.0000 - fp: 24.0000 - tn: 2745.0000 - fn: 53.0000 - accuracy: 0.9862 - precision: 0.9914 - recall: 0.9813 - auc: 0.9982 - val_loss: 0.0421 - val_tp: 1059.0000 - val_fp: 16.0000 - val_tn: 124.0000 - val_fn: 1.0000 - val_accuracy: 0.9858 - val_precision: 0.9851 - val_recall: 0.9991 - val_auc: 0.9916
# Epoch 14/20
# 350/350 [==============================] - 19s 54ms/step - loss: 0.0387 - tp: 2755.0000 - fp: 20.0000 - tn: 2789.0000 - fn: 36.0000 - accuracy: 0.9900 - precision: 0.9928 - recall: 0.9871 - auc: 0.9979 - val_loss: 0.0386 - val_tp: 1042.0000 - val_fp: 1.0000 - val_tn: 139.0000 - val_fn: 18.0000 - val_accuracy: 0.9842 - val_precision: 0.9990 - val_recall: 0.9830 - val_auc: 0.9989
# Epoch 15/20
# 350/350 [==============================] - 19s 54ms/step - loss: 0.0437 - tp: 2769.0000 - fp: 29.0000 - tn: 2754.0000 - fn: 48.0000 - accuracy: 0.9862 - precision: 0.9896 - recall: 0.9830 - auc: 0.9982 - val_loss: 0.1388 - val_tp: 998.0000 - val_fp: 0.0000e+00 - val_tn: 140.0000 - val_fn: 62.0000 - val_accuracy: 0.9483 - val_precision: 1.0000 - val_recall: 0.9415 - val_auc: 0.9978
# Epoch 16/20
# 350/350 [==============================] - 19s 54ms/step - loss: 0.0415 - tp: 2732.0000 - fp: 22.0000 - tn: 2801.0000 - fn: 45.0000 - accuracy: 0.9880 - precision: 0.9920 - recall: 0.9838 - auc: 0.9978 - val_loss: 0.0565 - val_tp: 1037.0000 - val_fp: 2.0000 - val_tn: 138.0000 - val_fn: 23.0000 - val_accuracy: 0.9792 - val_precision: 0.9981 - val_recall: 0.9783 - val_auc: 0.9964
# Epoch 17/20
# 350/350 [==============================] - 19s 54ms/step - loss: 0.0401 - tp: 2746.0000 - fp: 25.0000 - tn: 2787.0000 - fn: 42.0000 - accuracy: 0.9880 - precision: 0.9910 - recall: 0.9849 - auc: 0.9979 - val_loss: 0.1432 - val_tp: 1006.0000 - val_fp: 0.0000e+00 - val_tn: 140.0000 - val_fn: 54.0000 - val_accuracy: 0.9550 - val_precision: 1.0000 - val_recall: 0.9491 - val_auc: 0.9954
# Epoch 18/20
# 350/350 [==============================] - 19s 54ms/step - loss: 0.0382 - tp: 2769.0000 - fp: 18.0000 - tn: 2767.0000 - fn: 46.0000 - accuracy: 0.9886 - precision: 0.9935 - recall: 0.9837 - auc: 0.9986 - val_loss: 0.1147 - val_tp: 1056.0000 - val_fp: 39.0000 - val_tn: 101.0000 - val_fn: 4.0000 - val_accuracy: 0.9642 - val_precision: 0.9644 - val_recall: 0.9962 - val_auc: 0.9856
# Epoch 19/20
# 350/350 [==============================] - 19s 54ms/step - loss: 0.0372 - tp: 2753.0000 - fp: 24.0000 - tn: 2786.0000 - fn: 37.0000 - accuracy: 0.9891 - precision: 0.9914 - recall: 0.9867 - auc: 0.9985 - val_loss: 0.0904 - val_tp: 1039.0000 - val_fp: 1.0000 - val_tn: 139.0000 - val_fn: 21.0000 - val_accuracy: 0.9817 - val_precision: 0.9990 - val_recall: 0.9802 - val_auc: 0.9945
# Epoch 20/20
# 350/350 [==============================] - 19s 54ms/step - loss: 0.0320 - tp: 2825.0000 - fp: 21.0000 - tn: 2720.0000 - fn: 34.0000 - accuracy: 0.9902 - precision: 0.9926 - recall: 0.9881 - auc: 0.9986 - val_loss: 0.0543 - val_tp: 1044.0000 - val_fp: 0.0000e+00 - val_tn: 140.0000 - val_fn: 16.0000 - val_accuracy: 0.9867 - val_precision: 1.0000 - val_recall: 0.9849 - val_auc: 0.9983

# %%
plot_metrics(resampled_history)
plt.savefig(conf["log_dir"]+"/resampled_metrics_plot.pdf", format="pdf")

# %%
resampled_results = resampled_model.evaluate(val_ds_resampled, verbose=2, steps=conf["steps"]["val"])
print()

f = open(conf["log_dir"]+"/resampled_val_results.txt","w")
for name, value in zip(resampled_model.metrics_names, resampled_results):
    line = "{} : {}\n".format(name, value)
    print(line, end='')
    f.write(line)
f.close()
print()
# Out:
# 75/75 - 1s - loss: 0.0630 - tp: 1038.0000 - fp: 1.0000 - tn: 140.0000 - fn: 21.0000 - accuracy: 0.9817 - precision: 0.9990 - recall: 0.9802 - auc: 0.9980
#
# loss : 0.0629805326461792
# tp : 1038.0
# fp : 1.0
# tn : 140.0
# fn : 21.0
# accuracy : 0.9816666841506958
# precision : 0.9990375638008118
# recall : 0.980169951915741
# auc : 0.9979574084281921

# %%
train_labels_resampled, train_predictions_resampled = numpify(train_ds_resampled, resampled_model, samples=5000)
val_labels_resampled, val_predictions_resampled = numpify(val_ds_resampled, resampled_model, samples=5000)

# %%
plot_cm(train_labels_resampled, train_predictions_resampled)
plt.savefig(conf["log_dir"]+"/resampled_cm_plot.pdf", format="pdf")
# Out:
# Legitimate Lesions Detected (True Negatives):  2404
# Legitimate Lesions Incorrectly Detected (False Positives):  0
# Fraudulent Lesions Missed (False Negatives):  44
# Fraudulent Lesions Detected (True Positives):  2552
# Total Fraudulent Lesions:  2596

# %%
plt.figure(figsize=(10,10))

plot_roc("Train Baseline", train_labels_baseline, train_predictions_baseline, color=colors[0])
plot_roc("Val Baseline", val_labels_baseline, val_predictions_baseline, color=colors[0], linestyle='--')

plot_roc("Train Weighted", train_labels_weighted, train_predictions_weighted, color=colors[1])
plot_roc("Val Weighted", val_labels_weighted, val_predictions_weighted, color=colors[1], linestyle='--')

plot_roc("Train Resampled", train_labels_resampled, train_predictions_resampled, color=colors[2])
plot_roc("Val Resampled", val_labels_resampled, val_predictions_resampled, color=colors[2], linestyle='--')

plt.legend(loc='lower right');
plt.savefig(conf["log_dir"]+"/resampled_roc_plot.pdf", format="pdf")
