# %% [markdown]
# CIFAR10 dataset trained on all classes with resnet56 without augmentation.

# %% [markdown]
# ### Loading images
# https://www.tensorflow.org/tutorials/load_data/images

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf

import numpy as np
import os
import pathlib
import matplotlib.pyplot as plt

# Some stuff to make utils-function work
import sys
sys.path.append('/home/henrik/master_thesis/code/utils')
from data_prep import create_dataset, print_class_info, show_image
# %load_ext autoreload
# %autoreload 2

# Jupyter-specific
# %matplotlib inline

# %% [markdown]
# Some parameters

# %%
data_dir = pathlib.Path('/mnt/sdb/kvasir-dataset-v2/')

config = {
    "data_dir": data_dir,
    "cache_dir": "./cache",
    "MODEL": 'resnet56',
    "DS_INFO": 'complete',
    "resample": True,
    "neg_class": ['ship'],
    "NUM_EPOCHS": 40,
    "BATCH_SIZE": 64,
    "IMG_SIZE": (128, 128, 3),
    "outcast": None,
    "verbosity": 1
    }

model_name = '{}x{}x{}_{}_{}'.format(config["NUM_EPOCHS"], config["BATCH_SIZE"], 
                                     config["IMG_SIZE"][1], config["DS_INFO"], config["MODEL"])

# %% [markdown]
# Create training, testing and validation dataset from utils/data_prep.py

# %%
train_ds, test_ds, val_ds, params = create_dataset(config)
# Out:
# Directories:  ['esophagitis' 'normal-pylorus' 'ulcerative-colitis' 'normal-cecum'
#  'normal-z-line' 'polyps' 'dyed-resection-margins' 'dyed-lifted-polyps']
#
# esophagitis       : 1000
# normal-pylorus    : 1000
# ulcerative-colitis: 1000
# normal-cecum      : 1000
# normal-z-line     : 1000
# polyps            : 1000
# dyed-resection-margins: 1000
# dyed-lifted-polyps: 1000
#
# Total number of images: 8000, in 8 classes
# Dataset.list_files:  /mnt/sdb/kvasir-dataset-v2/*/*.*g
#
# WARNING:tensorflow:Entity <function create_dataset.<locals>.get_label at 0x7efdc9117680> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Cell is empty
# WARNING: Entity <function create_dataset.<locals>.get_label at 0x7efdc9117680> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Cell is empty
# [6 2 6 7 5 5 5 4 4 5]
# [5 2 6 6 2 7 2 5 4 7]
# [3 4 7 4 4 2 6 1 5 2]
# [7 6 0 1 4 3 6 3 3 0]
# [0 7 2 7 1 5 0 3 3 7]
# [7 5 4 7 7 6 0 2 2 0]
# [0 1 6 3 5 0 7 0 6 2]
# [6 6 2 2 0 3 0 3 3 2]
# [6 3 3 7 2 1 7 7 0 7]
# [7 4 6 3 6 2 5 4 0 6]
#
# Full dataset sample size:         8000
# Train dataset sample size:        5600
# Test dataset sample size:         1200
# Validation dataset sample size:   1200

# %% [markdown]
# ## Training

# %% [markdown]
# ### Resnet56 (not pretrained)
# See https://lambdalabs.com/blog/tensorflow-2-0-tutorial-01-image-classification-basics/
#
# https://github.com/lambdal/TensorFlow2-tutorial/tree/master/01-basic-image-classification

# %%
import resnet
import datetime
from tensorflow.keras.callbacks import TensorBoard, LearningRateScheduler

NUM_GPUS = 1
BS_PER_GPU = config["BATCH_SIZE"]
BASE_LEARNING_RATE = 0.1
LR_SCHEDULE = [(0.1, 30), (0.01, 45)]

# %%
PATH = os.getenv('PATH')
# %env PATH=/home/henrik/anaconda3/envs/TF2/bin:$PATH
# Out:
# env: PATH=/home/henrik/anaconda3/envs/TF2/bin:/home/henrik/anaconda3/envs/TF2/bin:/home/henrik/anaconda3/condabin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin:/home/henrik/.dotnet/tools

# %%
def schedule(epoch):
    initial_learning_rate = BASE_LEARNING_RATE * BS_PER_GPU / 128
    learning_rate = initial_learning_rate
    for mult, start_epoch in LR_SCHEDULE:
        if epoch >= start_epoch:
            learning_rate = initial_learning_rate * mult
        else:
            break
    tf.summary.scalar('learning rate', data=learning_rate, step=epoch)
    return learning_rate

# %% [markdown]
# Create and compile the model

# %%
img_input = tf.keras.layers.Input(shape=config["IMG_SIZE"])
opt = tf.keras.optimizers.SGD(learning_rate=0.1, momentum=0.9)

if NUM_GPUS == 1:
    resnet56_model = resnet.resnet56(img_input=img_input, classes=params["NUM_CLASSES"])
    resnet56_model.compile(
              optimizer=opt,
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])
else:
    mirrored_strategy = tf.distribute.MirroredStrategy()
    with mirrored_strategy.scope():
        resnet56_model = resnet.resnet56(img_input=img_input, classes=params["NUM_CLASSES"])
        resnet56_model.compile(
                optimizer=opt,
                loss='sparse_categorical_crossentropy',
                metrics=['sparse_categorical_accuracy'])

# %%
if config["verbosity"] > 0:
    resnet56_model.summary()
# Out:
# Model: "resnet56"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 130, 130, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 128, 128, 16) 448         conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 128, 128, 16) 64          conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 128, 16) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# res2block_0_branch2a (Conv2D)   (None, 128, 128, 16) 2320        activation[0][0]
# __________________________________________________________________________________________________
# bn2block_0_branch2a (BatchNorma (None, 128, 128, 16) 64          res2block_0_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 16) 0           bn2block_0_branch2a[0][0]
# __________________________________________________________________________________________________
# res2block_0_branch2b (Conv2D)   (None, 128, 128, 16) 2320        activation_1[0][0]
# __________________________________________________________________________________________________
# res2block_0_branch1 (Conv2D)    (None, 128, 128, 16) 272         activation[0][0]
# __________________________________________________________________________________________________
# bn2block_0_branch2b (BatchNorma (None, 128, 128, 16) 64          res2block_0_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2block_0_branch1 (BatchNormal (None, 128, 128, 16) 64          res2block_0_branch1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 128, 128, 16) 0           bn2block_0_branch2b[0][0]
#                                                                  bn2block_0_branch1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 16) 0           add[0][0]
# __________________________________________________________________________________________________
# res2block_1_branch2a (Conv2D)   (None, 128, 128, 16) 2320        activation_2[0][0]
# __________________________________________________________________________________________________
# bn2block_1_branch2a (BatchNorma (None, 128, 128, 16) 64          res2block_1_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 16) 0           bn2block_1_branch2a[0][0]
# __________________________________________________________________________________________________
# res2block_1_branch2b (Conv2D)   (None, 128, 128, 16) 2320        activation_3[0][0]
# __________________________________________________________________________________________________
# bn2block_1_branch2b (BatchNorma (None, 128, 128, 16) 64          res2block_1_branch2b[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 16) 0           bn2block_1_branch2b[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 128, 128, 16) 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2block_2_branch2a (Conv2D)   (None, 128, 128, 16) 2320        activation_4[0][0]
# __________________________________________________________________________________________________
# bn2block_2_branch2a (BatchNorma (None, 128, 128, 16) 64          res2block_2_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 128, 128, 16) 0           bn2block_2_branch2a[0][0]
# __________________________________________________________________________________________________
# res2block_2_branch2b (Conv2D)   (None, 128, 128, 16) 2320        activation_5[0][0]
# __________________________________________________________________________________________________
# bn2block_2_branch2b (BatchNorma (None, 128, 128, 16) 64          res2block_2_branch2b[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 128, 128, 16) 0           bn2block_2_branch2b[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 128, 128, 16) 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2block_3_branch2a (Conv2D)   (None, 128, 128, 16) 2320        activation_6[0][0]
# __________________________________________________________________________________________________
# bn2block_3_branch2a (BatchNorma (None, 128, 128, 16) 64          res2block_3_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 128, 128, 16) 0           bn2block_3_branch2a[0][0]
# __________________________________________________________________________________________________
# res2block_3_branch2b (Conv2D)   (None, 128, 128, 16) 2320        activation_7[0][0]
# __________________________________________________________________________________________________
# bn2block_3_branch2b (BatchNorma (None, 128, 128, 16) 64          res2block_3_branch2b[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 128, 16) 0           bn2block_3_branch2b[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 128, 128, 16) 0           add_3[0][0]
# __________________________________________________________________________________________________
# res2block_4_branch2a (Conv2D)   (None, 128, 128, 16) 2320        activation_8[0][0]
# __________________________________________________________________________________________________
# bn2block_4_branch2a (BatchNorma (None, 128, 128, 16) 64          res2block_4_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 128, 128, 16) 0           bn2block_4_branch2a[0][0]
# __________________________________________________________________________________________________
# res2block_4_branch2b (Conv2D)   (None, 128, 128, 16) 2320        activation_9[0][0]
# __________________________________________________________________________________________________
# bn2block_4_branch2b (BatchNorma (None, 128, 128, 16) 64          res2block_4_branch2b[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 128, 16) 0           bn2block_4_branch2b[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 128, 128, 16) 0           add_4[0][0]
# __________________________________________________________________________________________________
# res2block_5_branch2a (Conv2D)   (None, 128, 128, 16) 2320        activation_10[0][0]
# __________________________________________________________________________________________________
# bn2block_5_branch2a (BatchNorma (None, 128, 128, 16) 64          res2block_5_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 128, 128, 16) 0           bn2block_5_branch2a[0][0]
# __________________________________________________________________________________________________
# res2block_5_branch2b (Conv2D)   (None, 128, 128, 16) 2320        activation_11[0][0]
# __________________________________________________________________________________________________
# bn2block_5_branch2b (BatchNorma (None, 128, 128, 16) 64          res2block_5_branch2b[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 128, 128, 16) 0           bn2block_5_branch2b[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 128, 128, 16) 0           add_5[0][0]
# __________________________________________________________________________________________________
# res2block_6_branch2a (Conv2D)   (None, 128, 128, 16) 2320        activation_12[0][0]
# __________________________________________________________________________________________________
# bn2block_6_branch2a (BatchNorma (None, 128, 128, 16) 64          res2block_6_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 128, 128, 16) 0           bn2block_6_branch2a[0][0]
# __________________________________________________________________________________________________
# res2block_6_branch2b (Conv2D)   (None, 128, 128, 16) 2320        activation_13[0][0]
# __________________________________________________________________________________________________
# bn2block_6_branch2b (BatchNorma (None, 128, 128, 16) 64          res2block_6_branch2b[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 128, 128, 16) 0           bn2block_6_branch2b[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 128, 128, 16) 0           add_6[0][0]
# __________________________________________________________________________________________________
# res2block_7_branch2a (Conv2D)   (None, 128, 128, 16) 2320        activation_14[0][0]
# __________________________________________________________________________________________________
# bn2block_7_branch2a (BatchNorma (None, 128, 128, 16) 64          res2block_7_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 128, 128, 16) 0           bn2block_7_branch2a[0][0]
# __________________________________________________________________________________________________
# res2block_7_branch2b (Conv2D)   (None, 128, 128, 16) 2320        activation_15[0][0]
# __________________________________________________________________________________________________
# bn2block_7_branch2b (BatchNorma (None, 128, 128, 16) 64          res2block_7_branch2b[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 128, 128, 16) 0           bn2block_7_branch2b[0][0]
#                                                                  activation_14[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 128, 128, 16) 0           add_7[0][0]
# __________________________________________________________________________________________________
# res2block_8_branch2a (Conv2D)   (None, 128, 128, 16) 2320        activation_16[0][0]
# __________________________________________________________________________________________________
# bn2block_8_branch2a (BatchNorma (None, 128, 128, 16) 64          res2block_8_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 128, 128, 16) 0           bn2block_8_branch2a[0][0]
# __________________________________________________________________________________________________
# res2block_8_branch2b (Conv2D)   (None, 128, 128, 16) 2320        activation_17[0][0]
# __________________________________________________________________________________________________
# bn2block_8_branch2b (BatchNorma (None, 128, 128, 16) 64          res2block_8_branch2b[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 128, 128, 16) 0           bn2block_8_branch2b[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 128, 128, 16) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res3block_0_branch2a (Conv2D)   (None, 64, 64, 32)   4640        activation_18[0][0]
# __________________________________________________________________________________________________
# bn3block_0_branch2a (BatchNorma (None, 64, 64, 32)   128         res3block_0_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 64, 64, 32)   0           bn3block_0_branch2a[0][0]
# __________________________________________________________________________________________________
# res3block_0_branch2b (Conv2D)   (None, 64, 64, 32)   9248        activation_19[0][0]
# __________________________________________________________________________________________________
# res3block_0_branch1 (Conv2D)    (None, 64, 64, 32)   544         activation_18[0][0]
# __________________________________________________________________________________________________
# bn3block_0_branch2b (BatchNorma (None, 64, 64, 32)   128         res3block_0_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3block_0_branch1 (BatchNormal (None, 64, 64, 32)   128         res3block_0_branch1[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 64, 32)   0           bn3block_0_branch2b[0][0]
#                                                                  bn3block_0_branch1[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 64, 64, 32)   0           add_9[0][0]
# __________________________________________________________________________________________________
# res3block_1_branch2a (Conv2D)   (None, 64, 64, 32)   9248        activation_20[0][0]
# __________________________________________________________________________________________________
# bn3block_1_branch2a (BatchNorma (None, 64, 64, 32)   128         res3block_1_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 64, 64, 32)   0           bn3block_1_branch2a[0][0]
# __________________________________________________________________________________________________
# res3block_1_branch2b (Conv2D)   (None, 64, 64, 32)   9248        activation_21[0][0]
# __________________________________________________________________________________________________
# bn3block_1_branch2b (BatchNorma (None, 64, 64, 32)   128         res3block_1_branch2b[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 64, 64, 32)   0           bn3block_1_branch2b[0][0]
#                                                                  activation_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 64, 64, 32)   0           add_10[0][0]
# __________________________________________________________________________________________________
# res3block_2_branch2a (Conv2D)   (None, 64, 64, 32)   9248        activation_22[0][0]
# __________________________________________________________________________________________________
# bn3block_2_branch2a (BatchNorma (None, 64, 64, 32)   128         res3block_2_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 64, 64, 32)   0           bn3block_2_branch2a[0][0]
# __________________________________________________________________________________________________
# res3block_2_branch2b (Conv2D)   (None, 64, 64, 32)   9248        activation_23[0][0]
# __________________________________________________________________________________________________
# bn3block_2_branch2b (BatchNorma (None, 64, 64, 32)   128         res3block_2_branch2b[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 64, 64, 32)   0           bn3block_2_branch2b[0][0]
#                                                                  activation_22[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 64, 64, 32)   0           add_11[0][0]
# __________________________________________________________________________________________________
# res3block_3_branch2a (Conv2D)   (None, 64, 64, 32)   9248        activation_24[0][0]
# __________________________________________________________________________________________________
# bn3block_3_branch2a (BatchNorma (None, 64, 64, 32)   128         res3block_3_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 64, 64, 32)   0           bn3block_3_branch2a[0][0]
# __________________________________________________________________________________________________
# res3block_3_branch2b (Conv2D)   (None, 64, 64, 32)   9248        activation_25[0][0]
# __________________________________________________________________________________________________
# bn3block_3_branch2b (BatchNorma (None, 64, 64, 32)   128         res3block_3_branch2b[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 64, 64, 32)   0           bn3block_3_branch2b[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 64, 64, 32)   0           add_12[0][0]
# __________________________________________________________________________________________________
# res3block_4_branch2a (Conv2D)   (None, 64, 64, 32)   9248        activation_26[0][0]
# __________________________________________________________________________________________________
# bn3block_4_branch2a (BatchNorma (None, 64, 64, 32)   128         res3block_4_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 64, 64, 32)   0           bn3block_4_branch2a[0][0]
# __________________________________________________________________________________________________
# res3block_4_branch2b (Conv2D)   (None, 64, 64, 32)   9248        activation_27[0][0]
# __________________________________________________________________________________________________
# bn3block_4_branch2b (BatchNorma (None, 64, 64, 32)   128         res3block_4_branch2b[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 64, 64, 32)   0           bn3block_4_branch2b[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 64, 64, 32)   0           add_13[0][0]
# __________________________________________________________________________________________________
# res3block_5_branch2a (Conv2D)   (None, 64, 64, 32)   9248        activation_28[0][0]
# __________________________________________________________________________________________________
# bn3block_5_branch2a (BatchNorma (None, 64, 64, 32)   128         res3block_5_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 64, 64, 32)   0           bn3block_5_branch2a[0][0]
# __________________________________________________________________________________________________
# res3block_5_branch2b (Conv2D)   (None, 64, 64, 32)   9248        activation_29[0][0]
# __________________________________________________________________________________________________
# bn3block_5_branch2b (BatchNorma (None, 64, 64, 32)   128         res3block_5_branch2b[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 64, 64, 32)   0           bn3block_5_branch2b[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 64, 64, 32)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res3block_6_branch2a (Conv2D)   (None, 64, 64, 32)   9248        activation_30[0][0]
# __________________________________________________________________________________________________
# bn3block_6_branch2a (BatchNorma (None, 64, 64, 32)   128         res3block_6_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 64, 64, 32)   0           bn3block_6_branch2a[0][0]
# __________________________________________________________________________________________________
# res3block_6_branch2b (Conv2D)   (None, 64, 64, 32)   9248        activation_31[0][0]
# __________________________________________________________________________________________________
# bn3block_6_branch2b (BatchNorma (None, 64, 64, 32)   128         res3block_6_branch2b[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 64, 64, 32)   0           bn3block_6_branch2b[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 64, 64, 32)   0           add_15[0][0]
# __________________________________________________________________________________________________
# res3block_7_branch2a (Conv2D)   (None, 64, 64, 32)   9248        activation_32[0][0]
# __________________________________________________________________________________________________
# bn3block_7_branch2a (BatchNorma (None, 64, 64, 32)   128         res3block_7_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 64, 64, 32)   0           bn3block_7_branch2a[0][0]
# __________________________________________________________________________________________________
# res3block_7_branch2b (Conv2D)   (None, 64, 64, 32)   9248        activation_33[0][0]
# __________________________________________________________________________________________________
# bn3block_7_branch2b (BatchNorma (None, 64, 64, 32)   128         res3block_7_branch2b[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 64, 64, 32)   0           bn3block_7_branch2b[0][0]
#                                                                  activation_32[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 64, 64, 32)   0           add_16[0][0]
# __________________________________________________________________________________________________
# res3block_8_branch2a (Conv2D)   (None, 64, 64, 32)   9248        activation_34[0][0]
# __________________________________________________________________________________________________
# bn3block_8_branch2a (BatchNorma (None, 64, 64, 32)   128         res3block_8_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 64, 64, 32)   0           bn3block_8_branch2a[0][0]
# __________________________________________________________________________________________________
# res3block_8_branch2b (Conv2D)   (None, 64, 64, 32)   9248        activation_35[0][0]
# __________________________________________________________________________________________________
# bn3block_8_branch2b (BatchNorma (None, 64, 64, 32)   128         res3block_8_branch2b[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 64, 64, 32)   0           bn3block_8_branch2b[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 64, 64, 32)   0           add_17[0][0]
# __________________________________________________________________________________________________
# res4block_0_branch2a (Conv2D)   (None, 32, 32, 64)   18496       activation_36[0][0]
# __________________________________________________________________________________________________
# bn4block_0_branch2a (BatchNorma (None, 32, 32, 64)   256         res4block_0_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 32, 32, 64)   0           bn4block_0_branch2a[0][0]
# __________________________________________________________________________________________________
# res4block_0_branch2b (Conv2D)   (None, 32, 32, 64)   36928       activation_37[0][0]
# __________________________________________________________________________________________________
# res4block_0_branch1 (Conv2D)    (None, 32, 32, 64)   2112        activation_36[0][0]
# __________________________________________________________________________________________________
# bn4block_0_branch2b (BatchNorma (None, 32, 32, 64)   256         res4block_0_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4block_0_branch1 (BatchNormal (None, 32, 32, 64)   256         res4block_0_branch1[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 32, 32, 64)   0           bn4block_0_branch2b[0][0]
#                                                                  bn4block_0_branch1[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 32, 32, 64)   0           add_18[0][0]
# __________________________________________________________________________________________________
# res4block_1_branch2a (Conv2D)   (None, 32, 32, 64)   36928       activation_38[0][0]
# __________________________________________________________________________________________________
# bn4block_1_branch2a (BatchNorma (None, 32, 32, 64)   256         res4block_1_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 32, 32, 64)   0           bn4block_1_branch2a[0][0]
# __________________________________________________________________________________________________
# res4block_1_branch2b (Conv2D)   (None, 32, 32, 64)   36928       activation_39[0][0]
# __________________________________________________________________________________________________
# bn4block_1_branch2b (BatchNorma (None, 32, 32, 64)   256         res4block_1_branch2b[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 32, 32, 64)   0           bn4block_1_branch2b[0][0]
#                                                                  activation_38[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 32, 32, 64)   0           add_19[0][0]
# __________________________________________________________________________________________________
# res4block_2_branch2a (Conv2D)   (None, 32, 32, 64)   36928       activation_40[0][0]
# __________________________________________________________________________________________________
# bn4block_2_branch2a (BatchNorma (None, 32, 32, 64)   256         res4block_2_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 32, 64)   0           bn4block_2_branch2a[0][0]
# __________________________________________________________________________________________________
# res4block_2_branch2b (Conv2D)   (None, 32, 32, 64)   36928       activation_41[0][0]
# __________________________________________________________________________________________________
# bn4block_2_branch2b (BatchNorma (None, 32, 32, 64)   256         res4block_2_branch2b[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 32, 32, 64)   0           bn4block_2_branch2b[0][0]
#                                                                  activation_40[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 32, 64)   0           add_20[0][0]
# __________________________________________________________________________________________________
# res4block_3_branch2a (Conv2D)   (None, 32, 32, 64)   36928       activation_42[0][0]
# __________________________________________________________________________________________________
# bn4block_3_branch2a (BatchNorma (None, 32, 32, 64)   256         res4block_3_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 32, 64)   0           bn4block_3_branch2a[0][0]
# __________________________________________________________________________________________________
# res4block_3_branch2b (Conv2D)   (None, 32, 32, 64)   36928       activation_43[0][0]
# __________________________________________________________________________________________________
# bn4block_3_branch2b (BatchNorma (None, 32, 32, 64)   256         res4block_3_branch2b[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 32, 32, 64)   0           bn4block_3_branch2b[0][0]
#                                                                  activation_42[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 32, 32, 64)   0           add_21[0][0]
# __________________________________________________________________________________________________
# res4block_4_branch2a (Conv2D)   (None, 32, 32, 64)   36928       activation_44[0][0]
# __________________________________________________________________________________________________
# bn4block_4_branch2a (BatchNorma (None, 32, 32, 64)   256         res4block_4_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 32, 32, 64)   0           bn4block_4_branch2a[0][0]
# __________________________________________________________________________________________________
# res4block_4_branch2b (Conv2D)   (None, 32, 32, 64)   36928       activation_45[0][0]
# __________________________________________________________________________________________________
# bn4block_4_branch2b (BatchNorma (None, 32, 32, 64)   256         res4block_4_branch2b[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 32, 32, 64)   0           bn4block_4_branch2b[0][0]
#                                                                  activation_44[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 32, 32, 64)   0           add_22[0][0]
# __________________________________________________________________________________________________
# res4block_5_branch2a (Conv2D)   (None, 32, 32, 64)   36928       activation_46[0][0]
# __________________________________________________________________________________________________
# bn4block_5_branch2a (BatchNorma (None, 32, 32, 64)   256         res4block_5_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 32, 32, 64)   0           bn4block_5_branch2a[0][0]
# __________________________________________________________________________________________________
# res4block_5_branch2b (Conv2D)   (None, 32, 32, 64)   36928       activation_47[0][0]
# __________________________________________________________________________________________________
# bn4block_5_branch2b (BatchNorma (None, 32, 32, 64)   256         res4block_5_branch2b[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 32, 32, 64)   0           bn4block_5_branch2b[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 32, 32, 64)   0           add_23[0][0]
# __________________________________________________________________________________________________
# res4block_6_branch2a (Conv2D)   (None, 32, 32, 64)   36928       activation_48[0][0]
# __________________________________________________________________________________________________
# bn4block_6_branch2a (BatchNorma (None, 32, 32, 64)   256         res4block_6_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 32, 32, 64)   0           bn4block_6_branch2a[0][0]
# __________________________________________________________________________________________________
# res4block_6_branch2b (Conv2D)   (None, 32, 32, 64)   36928       activation_49[0][0]
# __________________________________________________________________________________________________
# bn4block_6_branch2b (BatchNorma (None, 32, 32, 64)   256         res4block_6_branch2b[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 32, 32, 64)   0           bn4block_6_branch2b[0][0]
#                                                                  activation_48[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 32, 32, 64)   0           add_24[0][0]
# __________________________________________________________________________________________________
# res4block_7_branch2a (Conv2D)   (None, 32, 32, 64)   36928       activation_50[0][0]
# __________________________________________________________________________________________________
# bn4block_7_branch2a (BatchNorma (None, 32, 32, 64)   256         res4block_7_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 32, 32, 64)   0           bn4block_7_branch2a[0][0]
# __________________________________________________________________________________________________
# res4block_7_branch2b (Conv2D)   (None, 32, 32, 64)   36928       activation_51[0][0]
# __________________________________________________________________________________________________
# bn4block_7_branch2b (BatchNorma (None, 32, 32, 64)   256         res4block_7_branch2b[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 32, 32, 64)   0           bn4block_7_branch2b[0][0]
#                                                                  activation_50[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 32, 32, 64)   0           add_25[0][0]
# __________________________________________________________________________________________________
# res4block_8_branch2a (Conv2D)   (None, 32, 32, 64)   36928       activation_52[0][0]
# __________________________________________________________________________________________________
# bn4block_8_branch2a (BatchNorma (None, 32, 32, 64)   256         res4block_8_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 32, 32, 64)   0           bn4block_8_branch2a[0][0]
# __________________________________________________________________________________________________
# res4block_8_branch2b (Conv2D)   (None, 32, 32, 64)   36928       activation_53[0][0]
# __________________________________________________________________________________________________
# bn4block_8_branch2b (BatchNorma (None, 32, 32, 64)   256         res4block_8_branch2b[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 32, 32, 64)   0           bn4block_8_branch2b[0][0]
#                                                                  activation_52[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 32, 32, 64)   0           add_26[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 64)           0           activation_54[0][0]
# __________________________________________________________________________________________________
# fc10 (Dense)                    (None, 8)            520         avg_pool[0][0]
# ==================================================================================================
# Total params: 862,360
# Trainable params: 858,072
# Non-trainable params: 4,288
# __________________________________________________________________________________________________

# %% [raw]
# # Save image of layers
# tf.keras.utils.plot_model(resnet56_model, 'models/{}.png'.format(model_name), show_shapes=True)

# %%
log_dir="logs/resnet56/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
file_writer = tf.summary.create_file_writer(log_dir + "/metrics")
file_writer.set_as_default()

tensorboard_callback = tf.keras.callbacks.TensorBoard(
        log_dir=log_dir,
        update_freq='batch',
        histogram_freq=1)

lr_schedule_callback = LearningRateScheduler(schedule)

# %% [markdown]
# Train the model

# %%
history = resnet56_model.fit(
        train_ds,
        steps_per_epoch = params["train_size"] // config["BATCH_SIZE"],
        epochs = config["NUM_EPOCHS"],
        validation_data = test_ds,
        validation_steps = params["test_size"] // config["BATCH_SIZE"],
        validation_freq = 1,
        callbacks = [tensorboard_callback, lr_schedule_callback])
# Out:
# Train for 87 steps, validate for 18 steps
# Epoch 1/40
# 87/87 [==============================] - 29s 330ms/step - loss: 1.8213 - sparse_categorical_accuracy: 0.5896 - val_loss: 3.3543 - val_sparse_categorical_accuracy: 0.3108
# Epoch 2/40
# 87/87 [==============================] - 28s 327ms/step - loss: 1.7657 - sparse_categorical_accuracy: 0.6087 - val_loss: 2.2216 - val_sparse_categorical_accuracy: 0.4774
# Epoch 3/40
# 87/87 [==============================] - 28s 327ms/step - loss: 1.6857 - sparse_categorical_accuracy: 0.6202 - val_loss: 2.1937 - val_sparse_categorical_accuracy: 0.4566
# Epoch 4/40
# 87/87 [==============================] - 28s 327ms/step - loss: 1.6600 - sparse_categorical_accuracy: 0.6178 - val_loss: 2.3120 - val_sparse_categorical_accuracy: 0.4175
# Epoch 5/40
# 87/87 [==============================] - 29s 328ms/step - loss: 1.6037 - sparse_categorical_accuracy: 0.6315 - val_loss: 1.8823 - val_sparse_categorical_accuracy: 0.5182
# Epoch 6/40
# 87/87 [==============================] - 28s 327ms/step - loss: 1.5707 - sparse_categorical_accuracy: 0.6352 - val_loss: 2.2106 - val_sparse_categorical_accuracy: 0.3533
# Epoch 7/40
# 87/87 [==============================] - 28s 328ms/step - loss: 1.5239 - sparse_categorical_accuracy: 0.6455 - val_loss: 3.0328 - val_sparse_categorical_accuracy: 0.2726
# Epoch 8/40
# 87/87 [==============================] - 28s 327ms/step - loss: 1.5169 - sparse_categorical_accuracy: 0.6417 - val_loss: 2.1648 - val_sparse_categorical_accuracy: 0.4332
# Epoch 9/40
# 87/87 [==============================] - 29s 328ms/step - loss: 1.4899 - sparse_categorical_accuracy: 0.6406 - val_loss: 2.6251 - val_sparse_categorical_accuracy: 0.3845
# Epoch 10/40
# 87/87 [==============================] - 29s 329ms/step - loss: 1.4128 - sparse_categorical_accuracy: 0.6692 - val_loss: 2.1142 - val_sparse_categorical_accuracy: 0.5200
# Epoch 11/40
# 87/87 [==============================] - 28s 327ms/step - loss: 1.4007 - sparse_categorical_accuracy: 0.6620 - val_loss: 1.7956 - val_sparse_categorical_accuracy: 0.5200
# Epoch 12/40
# 87/87 [==============================] - 28s 325ms/step - loss: 1.3924 - sparse_categorical_accuracy: 0.6582 - val_loss: 1.9653 - val_sparse_categorical_accuracy: 0.5139
# Epoch 13/40
# 87/87 [==============================] - 28s 327ms/step - loss: 1.3394 - sparse_categorical_accuracy: 0.6668 - val_loss: 1.7914 - val_sparse_categorical_accuracy: 0.5278
# Epoch 14/40
# 87/87 [==============================] - 28s 327ms/step - loss: 1.3186 - sparse_categorical_accuracy: 0.6782 - val_loss: 1.7642 - val_sparse_categorical_accuracy: 0.4965
# Epoch 15/40
# 87/87 [==============================] - 28s 327ms/step - loss: 1.2911 - sparse_categorical_accuracy: 0.6803 - val_loss: 1.7020 - val_sparse_categorical_accuracy: 0.5035
# Epoch 16/40
# 87/87 [==============================] - 28s 325ms/step - loss: 1.2676 - sparse_categorical_accuracy: 0.6844 - val_loss: 1.8542 - val_sparse_categorical_accuracy: 0.5095
# Epoch 17/40
# 87/87 [==============================] - 29s 328ms/step - loss: 1.2269 - sparse_categorical_accuracy: 0.7017 - val_loss: 1.6151 - val_sparse_categorical_accuracy: 0.5538
# Epoch 18/40
# 87/87 [==============================] - 28s 327ms/step - loss: 1.2077 - sparse_categorical_accuracy: 0.6985 - val_loss: 3.0689 - val_sparse_categorical_accuracy: 0.2526
# Epoch 19/40
# 87/87 [==============================] - 28s 328ms/step - loss: 1.1672 - sparse_categorical_accuracy: 0.7082 - val_loss: 1.5845 - val_sparse_categorical_accuracy: 0.5556
# Epoch 20/40
# 87/87 [==============================] - 28s 327ms/step - loss: 1.1550 - sparse_categorical_accuracy: 0.7065 - val_loss: 1.8484 - val_sparse_categorical_accuracy: 0.4661
# Epoch 21/40
# 87/87 [==============================] - 29s 332ms/step - loss: 1.1365 - sparse_categorical_accuracy: 0.7148 - val_loss: 1.6873 - val_sparse_categorical_accuracy: 0.5564
# Epoch 22/40
# 87/87 [==============================] - 29s 328ms/step - loss: 1.1140 - sparse_categorical_accuracy: 0.7216 - val_loss: 1.8376 - val_sparse_categorical_accuracy: 0.4054
# Epoch 23/40
# 87/87 [==============================] - 28s 328ms/step - loss: 1.0802 - sparse_categorical_accuracy: 0.7344 - val_loss: 2.7249 - val_sparse_categorical_accuracy: 0.3108
# Epoch 24/40
# 87/87 [==============================] - 28s 326ms/step - loss: 1.0587 - sparse_categorical_accuracy: 0.7259 - val_loss: 1.4332 - val_sparse_categorical_accuracy: 0.5651
# Epoch 25/40
# 87/87 [==============================] - 28s 327ms/step - loss: 1.0676 - sparse_categorical_accuracy: 0.7193 - val_loss: 2.3834 - val_sparse_categorical_accuracy: 0.3420
# Epoch 26/40
# 87/87 [==============================] - 29s 328ms/step - loss: 1.0377 - sparse_categorical_accuracy: 0.7207 - val_loss: 2.9859 - val_sparse_categorical_accuracy: 0.2812
# Epoch 27/40
# 87/87 [==============================] - 28s 327ms/step - loss: 1.0149 - sparse_categorical_accuracy: 0.7344 - val_loss: 1.4798 - val_sparse_categorical_accuracy: 0.5330
# Epoch 28/40
# 87/87 [==============================] - 29s 331ms/step - loss: 1.0101 - sparse_categorical_accuracy: 0.7259 - val_loss: 2.2507 - val_sparse_categorical_accuracy: 0.4175
# Epoch 29/40
# 87/87 [==============================] - 29s 328ms/step - loss: 0.9953 - sparse_categorical_accuracy: 0.7347 - val_loss: 1.8797 - val_sparse_categorical_accuracy: 0.5434
# Epoch 30/40
# 87/87 [==============================] - 28s 327ms/step - loss: 0.9587 - sparse_categorical_accuracy: 0.7446 - val_loss: 1.6603 - val_sparse_categorical_accuracy: 0.4809
# Epoch 31/40
# 87/87 [==============================] - 29s 328ms/step - loss: 0.9216 - sparse_categorical_accuracy: 0.7610 - val_loss: 1.5079 - val_sparse_categorical_accuracy: 0.5052
# Epoch 32/40
# 87/87 [==============================] - 28s 325ms/step - loss: 0.9105 - sparse_categorical_accuracy: 0.7656 - val_loss: 1.3166 - val_sparse_categorical_accuracy: 0.5877
# Epoch 33/40
# 87/87 [==============================] - 28s 327ms/step - loss: 0.8835 - sparse_categorical_accuracy: 0.7775 - val_loss: 1.1227 - val_sparse_categorical_accuracy: 0.6649
# Epoch 34/40
# 87/87 [==============================] - 28s 328ms/step - loss: 0.8878 - sparse_categorical_accuracy: 0.7733 - val_loss: 1.1600 - val_sparse_categorical_accuracy: 0.6727
# Epoch 35/40
# 87/87 [==============================] - 29s 328ms/step - loss: 0.8822 - sparse_categorical_accuracy: 0.7802 - val_loss: 1.1006 - val_sparse_categorical_accuracy: 0.6719
# Epoch 36/40
# 87/87 [==============================] - 28s 327ms/step - loss: 0.8798 - sparse_categorical_accuracy: 0.7742 - val_loss: 0.9879 - val_sparse_categorical_accuracy: 0.7352
# Epoch 37/40
# 87/87 [==============================] - 28s 327ms/step - loss: 0.8800 - sparse_categorical_accuracy: 0.7800 - val_loss: 1.0538 - val_sparse_categorical_accuracy: 0.6997
# Epoch 38/40
# 87/87 [==============================] - 29s 328ms/step - loss: 0.8654 - sparse_categorical_accuracy: 0.7852 - val_loss: 0.9906 - val_sparse_categorical_accuracy: 0.7300
# Epoch 39/40
# 87/87 [==============================] - 29s 328ms/step - loss: 0.8674 - sparse_categorical_accuracy: 0.7847 - val_loss: 1.0273 - val_sparse_categorical_accuracy: 0.7161
# Epoch 40/40
# 87/87 [==============================] - 28s 325ms/step - loss: 0.8638 - sparse_categorical_accuracy: 0.7859 - val_loss: 1.0375 - val_sparse_categorical_accuracy: 0.7109

# %%
# resnet56_model.save('models/{}.h5'.format(model_name))
# resnet56_model = tf.keras.models.load_model('models/{}.h5'.format(model_name))

# %% [markdown]
# ## Evaluate the model

# %%
resnet56_evaluate = resnet56_model.evaluate(val_ds, verbose=2, steps=params["val_size"] // config["BATCH_SIZE"])
# Out:
# 18/18 - 2s - loss: 1.0589 - sparse_categorical_accuracy: 0.6962

# %%
acc = history.history['sparse_categorical_accuracy']
val_acc = history.history['val_sparse_categorical_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(config["NUM_EPOCHS"])

plt.figure(figsize=(14, 6))

# Subplot 1
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
# plt.ylim([0.5, 1])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')

# Subplot 2
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
# plt.ylim([0.5, 1])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# `Tensorboard`

# %% [raw]
# from tensorboard import notebook
# # Load the TensorBoard notebook extension
# # %load_ext tensorboard
#
# # Start tensorboard
# # %tensorboard --logdir logs

# %% [raw]
# # Clear any logs from previous runs (move to .old instead?)
# !rm -rf ./logs/
#
# # Stop tensorboard
# notebook.list()
# !kill 20058

# %% [markdown]
# ## Predict new samples

# %%
# Fetch one batch from validation dataset
images, labels = next(iter(val_ds))

# Convert from tensor to numpy array
images = images.numpy()
labels = labels.numpy()

# %%
# Get a random image and label
rand = np.random.randint(0, config["BATCH_SIZE"])
image = images[rand]
label = labels[rand]

# Predict one image
predictions = resnet56_model.predict(np.expand_dims(image, axis=0))[0]

for i, pred in enumerate(predictions):
    print("{:0.4f} {}".format(pred,params["class_names"][i]))

print ("\nLabel:", params["class_names"][label])
print ("Predicton:", params["class_names"][np.argmax(predictions)])

plt.figure(frameon=False, facecolor='white')
plt.imshow(image)
plt.axis('off');
# Out:
# 0.7763 esophagitis
# 0.0003 normal-pylorus
# 0.0002 ulcerative-colitis
# 0.0000 normal-cecum
# 0.2232 normal-z-line
# 0.0000 polyps
# 0.0000 dyed-resection-margins
# 0.0000 dyed-lifted-polyps
#
# Label: esophagitis
# Predicton: esophagitis

# %%
# Predict one batch
predictions = resnet56_model.predict(images)

print ('{:3}  {:<25} {:25}'.format('idx', 'label', 'pred'))
print ('---  {} {}'.format(25*'-', 25*'-'), end='')

for i, pred in enumerate(predictions):
    label = params["class_names"][labels[i]]
    prediction = params["class_names"][np.argmax(pred)]
    print ('\n{:3}  {:25} {:25}'.format(i, label, prediction), end='')
    if (label != prediction): print ("  Wrong", end='')
# Out:
# idx  label                     pred
# ---  ------------------------- -------------------------
#   0  normal-cecum              normal-cecum
#   1  ulcerative-colitis        ulcerative-colitis
#   2  esophagitis               normal-z-line              Wrong
#   3  dyed-resection-margins    esophagitis                Wrong
#   4  dyed-lifted-polyps        dyed-lifted-polyps
#   5  esophagitis               esophagitis
#   6  normal-cecum              normal-cecum
#   7  esophagitis               esophagitis
#   8  normal-pylorus            normal-pylorus
#   9  esophagitis               normal-z-line              Wrong
#  10  polyps                    ulcerative-colitis         Wrong
#  11  normal-z-line             normal-z-line
#  12  dyed-lifted-polyps        polyps                     Wrong
#  13  esophagitis               normal-z-line              Wrong
#  14  ulcerative-colitis        ulcerative-colitis
#  15  normal-z-line             normal-z-line
#  16  normal-cecum              normal-cecum
#  17  dyed-lifted-polyps        dyed-resection-margins     Wrong
#  18  polyps                    ulcerative-colitis         Wrong
#  19  dyed-resection-margins    dyed-resection-margins
#  20  esophagitis               esophagitis
#  21  esophagitis               esophagitis
#  22  polyps                    polyps
#  23  normal-cecum              ulcerative-colitis         Wrong
#  24  normal-cecum              normal-cecum
#  25  normal-z-line             normal-z-line
#  26  ulcerative-colitis        ulcerative-colitis
#  27  dyed-resection-margins    dyed-resection-margins
#  28  polyps                    normal-pylorus             Wrong
#  29  ulcerative-colitis        ulcerative-colitis
#  30  esophagitis               esophagitis
#  31  normal-pylorus            normal-pylorus
#  32  dyed-resection-margins    dyed-resection-margins
#  33  ulcerative-colitis        ulcerative-colitis
#  34  esophagitis               normal-z-line              Wrong
#  35  dyed-lifted-polyps        dyed-lifted-polyps
#  36  dyed-resection-margins    dyed-resection-margins
#  37  normal-cecum              normal-cecum
#  38  polyps                    ulcerative-colitis         Wrong
#  39  dyed-resection-margins    dyed-lifted-polyps         Wrong
#  40  polyps                    polyps
#  41  normal-z-line             normal-z-line
#  42  esophagitis               esophagitis
#  43  polyps                    ulcerative-colitis         Wrong
#  44  normal-pylorus            normal-pylorus
#  45  esophagitis               esophagitis
#  46  normal-cecum              polyps                     Wrong
#  47  dyed-resection-margins    dyed-lifted-polyps         Wrong
#  48  dyed-resection-margins    dyed-lifted-polyps         Wrong
#  49  ulcerative-colitis        ulcerative-colitis
#  50  polyps                    ulcerative-colitis         Wrong
#  51  esophagitis               esophagitis
#  52  ulcerative-colitis        ulcerative-colitis
#  53  polyps                    ulcerative-colitis         Wrong
#  54  normal-cecum              normal-cecum
#  55  esophagitis               esophagitis
#  56  dyed-lifted-polyps        ulcerative-colitis         Wrong
#  57  normal-cecum              normal-cecum
#  58  ulcerative-colitis        ulcerative-colitis
#  59  normal-cecum              normal-cecum
#  60  polyps                    ulcerative-colitis         Wrong
#  61  ulcerative-colitis        ulcerative-colitis
#  62  normal-pylorus            normal-pylorus
#  63  normal-z-line             esophagitis                Wrong
